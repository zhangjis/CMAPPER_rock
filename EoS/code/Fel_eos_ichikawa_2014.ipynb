# %%
import numpy as np
from scipy.optimize import root_scalar

# %pylab inline
import matplotlib.pyplot as plt
from matplotlib import cm
# %config InlineBackend.figure_format = 'retina'
plt.style.use('seaborn-whitegrid')
from scipy.interpolate import UnivariateSpline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /var/folders/tw/zmm3b0k97wbfj0cl53y3w2nm0000gn/T/ipykernel_64277/200498476.py:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
#------------------------------------------------------------------------------
# EOS and Material Parameters (from ichikawa 2014)
#------------------------------------------------------------------------------

# Number of atoms per formula unit (for monatomic Fe, n=1)
n = 1

# Avogadro's number (atoms/mol)
N_A = 6.02214076e23

# Reference temperature for the isothermal part (in K)
T0 = 7000.0

# Reference volume V0: given as 17.87 Å³/atom. T0 = 7000K and P0 = 0GPa
# Convert: 1 Å³ = 1e-30 m³, then multiply by Avogadro's number to get m³/mol.
V0 = 17.87e-30 * N_A  # m^3/mol
# For reference, V0 ≈ 1.075e-5 m^3/mol

# Isothermal bulk modulus at T0 (in Pa) and its pressure derivative.
# (Typical values for liquid iron are model dependent; use values from Ichikawa et al. (2014).)
K_T0 = 24.6e9    # Example: 100 GPa in Pa
Kp_T0 = 6.65   # Example value

# Grüneisen parameter parameters
gamma0 = 1.85      # Value at V0
b = 0.35           # Exponent

# Thermal energy fitting parameters.
# a is a multiplicative factor (here a = 1)
a = 1.0
# e0 is given as 0.314 in units of 10^{-4}/K, so convert to proper units:
e0 = 0.314e-4  # J/(mol·K^2)
g = -0.4       # exponent for volume scaling in the thermal energy term

# Universal gas constant in J/(mol·K)
R = 8.314

# Molar mass of iron in kg/mol (55.845 g/mol)
M = 0.055845

# Reference temperature (T0) for the isothermal (cold) curve (in K)
T0 = 7000.0

# range for the eos tables: T between 4000-7000 K and P between 60-420 GPa. 
# The calculation presented here is for T between 1000K and 50000 K and P bewteen 0 and 10 TPa. 
# Use at your own risk.

# %%
#------------------------------------------------------------------------------
# EOS Functions
#------------------------------------------------------------------------------

def P_T0(V):
    """
    Isothermal pressure at the reference temperature T0 using the Vinet (Morse-Rydberg) equation:
    
    P_T0(V) = 3 K_T0 (V/V0)^(-2/3) [1 - (V/V0)^(1/3)] * exp{ (3/2)(Kp_T0 - 1)[1 - (V/V0)^(1/3)] }
    """
    eta = (V / V0)**(1/3)
    prefactor = 3 * K_T0 * (V / V0)**(-2/3)
    exponent = (3/2) * (Kp_T0 - 1) * (1 - eta)
    return prefactor * (1 - eta) * np.exp(exponent)

def gamma_V(V):
    """
    Grüneisen parameter as a function of volume:
      gamma(V) = gamma0 * (V/V0)^b
    """
    return gamma0 * (1.0 + a * ((V / V0)**b - 1.0))

def E_th(V, T):
    """
    Thermal internal energy (J/mol) as a function of volume and temperature:
      E_th(V, T) = 3 n R (T + e0 (V/V0)^g T^2).
    """
    return 3.0 * n * R * (T + e0 * (V / V0)**g * T**2.0)

def delta_E_th(V, T):
    """
    Thermal energy difference relative to the reference temperature T0.
    """
    return E_th(V, T) - E_th(V, T0)

def P_total(V, T):
    """
    Total pressure from the EOS:
      P(V, T) = P_T0(V) + [gamma(V)/V] * delta_E_th(V, T)
    """
    return P_T0(V) + (gamma_V(V) / V) * delta_E_th(V, T)

# %%
#------------------------------------------------------------------------------
# Finite Difference Derivatives
#------------------------------------------------------------------------------

def dP_dV(V, T, delta=1e-10):
    """
    Compute the partial derivative ∂P/∂V|_T using central finite differences.
    """
    return (P_total(V + delta, T) - P_total(V - delta, T)) / (2 * delta)

def dP_dT(V, T, delta=1e-6):
    """
    Compute the partial derivative ∂P/∂T|_V using central finite differences.
    """
    return (P_total(V, T + delta) - P_total(V, T - delta)) / (2 * delta)

# %%
#------------------------------------------------------------------------------
# Specific Heats (Per Mole) and Conversion to Per Mass
#------------------------------------------------------------------------------

def specific_heat_Cv(V, T):
    """
    Specific heat at constant volume on a molar basis:
      C_V = dE_th/dT = 3 n R + 6 n R e0 (V/V0)^g T    (J/(mol·K))
    """
    return 3 * n * R + 6.0 * n * R * e0 * (V / V0)**g * T

def specific_heat_Cp(V, T):
    """
    Specific heat at constant pressure on a molar basis.
    
    Using the thermodynamic relation:
      C_P = C_V + T * ( (∂P/∂T|_V)^2 / (-∂P/∂V|_T) )
    """
    Cv = specific_heat_Cv(V, T)
    dP_dT_val = dP_dT(V, T)
    dP_dV_val = dP_dV(V, T)
    if np.isclose(dP_dV_val, 0.0):
        raise ValueError("dP/dV is too close to zero, cannot compute Cp reliably.")
    return Cv + T * (dP_dT_val**2) / (-dP_dV_val)

def convert_to_per_mass(value_per_mol):
    """
    Convert a quantity from a per-mole basis to a per-mass basis.
    For example, to convert specific heat from J/(mol·K) to J/(kg·K), divide by M.
    """
    return value_per_mol / M

# %%
#------------------------------------------------------------------------------
# Additional Thermodynamic Properties: Bulk Modulus and Thermal Expansion
#------------------------------------------------------------------------------

def isothermal_bulk_modulus(V, T):
    """
    Compute the isothermal bulk modulus at constant temperature:
      K_T = -V * (∂P/∂V)_T   (Pa)
    """
    return -V * dP_dV(V, T)

def thermal_expansion_coefficient(V, T):
    """
    Compute the thermal expansion coefficient:
      α = (1/V)(∂V/∂T)_P = (∂P/∂T)_V / K_T   (1/K)
    """
    dP_dT_val = dP_dT(V, T)
    K_T = isothermal_bulk_modulus(V, T)
    if np.isclose(K_T, 0.0):
        raise ValueError("Bulk modulus is zero, cannot compute thermal expansion coefficient.")
    return dP_dT_val / K_T

# %%
#------------------------------------------------------------------------------
# Root Finding to Invert the EOS (find V for given P and T)
#------------------------------------------------------------------------------

def residual(V, T, P_target):
    """
    Residual function for root-finding:
      f(V) = P_total(V, T) - P_target = 0.
    """
    return P_total(V, T) - P_target

def find_volume(P_target, T, V_guess):
    """
    Solve for V such that P_total(V, T) = P_target using a bracketing method.
    """
    V_lower = V_guess * 0.5
    V_upper = V_guess * 1.5
    sol = root_scalar(lambda V: residual(V, T, P_target),
                      bracket=[V_lower, V_upper],
                      method='brentq')
    if sol.converged:
        return sol.root
    else:
        raise RuntimeError("Volume root finding did not converge.")

# %%
#------------------------------------------------------------------------------
# Compute All Thermodynamic Properties
#------------------------------------------------------------------------------

def compute_properties(P_target, T, rho_guess, T_s0, V_s0):
    """
    Given a target pressure (in Pa) and temperature (in K), solve for the molar
    volume and compute:
      - Density (kg/m^3),
      - Thermal internal energy (J/mol and J/kg),
      - Thermal entropy (J/(mol·K) and J/(kg·K)),
      - Specific heats (C_V and C_P) in J/(mol·K) and J/(kg·K),
      - Isothermal bulk modulus (Pa),
      - Thermal expansion coefficient (1/K).
    """
    # Initial guess for volume (Molar mass divided by initial guess for density to find the guess in molar volume)
    V_guess = M / rho_guess
    V_sol = find_volume(P_target, T, V_guess)
    
    # Density: molar mass divided by molar volume (kg/m^3)
    density = M / V_sol
    
    # Thermal internal energy.
    internal_energy_mol = E_th(V_sol, T)
    internal_energy_mass = convert_to_per_mass(internal_energy_mol)
    
    # Thermal entropy (using S = 3 n R ln(T/T0) + 6 n R e0 (V/V0)^g (T - T0)).
    # T_s0 and V_s0 are the reference state for s = 0
    entropy_mol = 3 * n * R * np.log(T / T_s0) + 6 * n * R * e0 * (V_sol / V_s0)**g * (T - T_s0)
    entropy_mass = convert_to_per_mass(entropy_mol)
    
    # Specific heats.
    Cv_mol = specific_heat_Cv(V_sol, T)
    Cp_mol = specific_heat_Cp(V_sol, T)
    Cv_mass = convert_to_per_mass(Cv_mol)
    Cp_mass = convert_to_per_mass(Cp_mol)
    
    # Isothermal bulk modulus.
    bulk_modulus = isothermal_bulk_modulus(V_sol, T)
    
    # Thermal expansion coefficient.
    alpha = thermal_expansion_coefficient(V_sol, T)
    
    return {
        "molar_volume": V_sol,             # m^3/mol
        "density": density,                # kg/m^3
        "internal_energy_mol": internal_energy_mol,  # J/mol
        "internal_energy_mass": internal_energy_mass,  # J/kg
        "entropy_mol": entropy_mol,        # J/(mol·K)
        "entropy_mass": entropy_mass,      # J/(kg·K)
        "Cv_mol": Cv_mol,                  # J/(mol·K)
        "Cp_mol": Cp_mol,                  # J/(mol·K)
        "Cv_mass": Cv_mass,                # J/(kg·K)
        "Cp_mass": Cp_mass,                # J/(kg·K)
        "bulk_modulus": bulk_modulus,      # Pa
        "thermal_expansion": alpha         # 1/K
    }

# %%
def compute_density(P_target, T, rho_guess, T_s0, V_s0):
    """
    Computes density at given pressure (Pa) and temperature (K)
    using the EOS inversion routine.
    """
    try:
        props = compute_properties(P_target, T, rho_guess, T_s0, V_s0)
        return props["density"], props
    except Exception as e:
        # If the root-finding fails, return None to mark that we have no data.
        return None, None

# %% [markdown]
# #------------------------------------------------------------------------------
# # Main Routine: User Input and Output
# #------------------------------------------------------------------------------
#
# if __name__ == "__main__":
#     try:
#         P_input_GPa = float(input("Enter pressure (GPa): "))
#         T_input = float(input("Enter temperature (K): "))
#     except ValueError:
#         print("Invalid input. Please enter numerical values.")
#         exit(1)
#
#     # Convert pressure from GPa to Pa (1 GPa = 1e9 Pa)
#     P_input = P_input_GPa * 1e9
#
#     try:
#         props = compute_properties(P_input, T_input)
#         print("\n--- Computed Thermodynamic Properties ---")
#         print(f"Molar Volume:              {props['molar_volume']:.3e} m^3/mol")
#         print(f"Density:                   {props['density']:.3e} kg/m^3")
#         print(f"Internal Energy:           {props['internal_energy_mol']:.3e} J/mol "
#               f"({props['internal_energy_mass']:.3e} J/kg)")
#         print(f"Entropy:                   {props['entropy_mol']:.3e} J/(mol·K) "
#               f"({props['entropy_mass']:.3e} J/(kg·K))")
#         print(f"Specific Heat (C_V):       {props['Cv_mol']:.3e} J/(mol·K) "
#               f"({props['Cv_mass']:.3e} J/(kg·K))")
#         print(f"Specific Heat (C_P):       {props['Cp_mol']:.3e} J/(mol·K) "
#               f"({props['Cp_mass']:.3e} J/(kg·K))")
#         print(f"Isothermal Bulk Modulus:   {props['bulk_modulus']:.3e} Pa")
#         print(f"Thermal Expansion Coeff.:  {props['thermal_expansion']:.3e} 1/K")
#     except Exception as e:
#         print("Error computing properties:", e)

# %%
# initialize a pressure grid and 
# a rho_guess grid as the starting guess point for each pressure level with T = T_values[0], T_values defined below

P_grid_GPa = np.linspace(0.0, 10000.0, 1001)
#P_grid_GPa = np.linspace(0.0, 20.0, 201)
rho_guess_grid = np.zeros(len(P_grid_GPa))
# successful_rho saves the amount of successful calculations at each pressure level.
successful_rho = np.zeros(len(P_grid_GPa))

# define the T_grid
# T_values are temperatures where the EoS is known to work
# T_extrap will be used for extrapolation
# initialize to be the same so extrapolation is skipped if not needed

T_values = np.linspace(1000, 50000, 981)
T_extrap = np.linspace(1000, 50000, 981)

# This is the guess for P = P_grid_GPa[0] and T = T_values[0]
initial_rho_guess=6000.0

# for relative entropy, find the V of the reference state, T = 7000.0 and P = 0

T_s0 = T0
#V_guess_s0 = M / initial_rho_guess
#V_s0 = find_volume(P_grid_GPa[0]*1e9, T_s0, V_guess_s0)
V_s0 = V0
#print(f"Temperature and molar volume at the reference state where s = 0: T = ", T_s0, "V = ", V_s0)

# Find initial guess of rho for all pressure levels at T = T0; We picked this as the starting point 
# because there's a solution to rho at every pressure levels in the grid.

T_start = T_values[0]

for i in range(len(P_grid_GPa)): 
    if i == 0:
        rho_guess = initial_rho_guess
    else:
        if rho_guess_grid[i-1] is None:
            rho_guess = initial_rho_guess
        else:
            rho_guess = rho_guess_grid[i-1]
    
    dens, props_list = compute_density(P_grid_GPa[i]*1e9, T_start, rho_guess, T_s0, V_s0)
    if dens is not None:
        rho_guess_grid[i] = dens
    else:
        # If the EOS fails, you might choose to skip or break out of the loop.
        rho_guess_grid[i] = np.nan
        
# perform an spline extrapolation if there is nan in rho_guess_grid ------ need to finish!!!!!!!
mask = np.isfinite(rho_guess_grid)
P_fit = P_grid_GPa[mask]
rho_guess_fit = rho_guess_grid[mask]

if len(rho_guess_fit)==len(rho_guess_grid):
    print('extrapolation for initial guess of rho at each pressure levels not needed.')
#print(len(rho_guess_fit)-len(rho_guess_grid))
# Out:
# extrapolation for initial guess of rho at each pressure levels not needed.

# %%
# compute the table

# initialize 2D arrays

rho_table = np.zeros((len(P_grid_GPa), len(T_extrap)))
Eth_table = np.zeros((len(P_grid_GPa), len(T_extrap)))
alpha_table = np.zeros((len(P_grid_GPa), len(T_extrap)))
cP_table = np.zeros((len(P_grid_GPa), len(T_extrap)))
cV_table = np.zeros((len(P_grid_GPa), len(T_extrap)))
s_table = np.zeros((len(P_grid_GPa), len(T_extrap)))
KT_table = np.zeros((len(P_grid_GPa), len(T_extrap)))

# %%
for i in range(len(P_grid_GPa)):
    # Choose a fixed pressure level
    P_target_GPa = P_grid_GPa[i]
    P_target = P_target_GPa * 1e9  # convert to Pa

    density_values = []
    entropy_values = []
    alpha_values = []
    Eth_values = []
    cP_values = []
    cV_values = []
    KT_values = []

    # Compute density and other quantities at temperatures where eos probably works.
    for T in T_values:
        if T == T_values[0]:
            rho_guess = rho_guess_grid[i]
        else:
            if np.isfinite(density_values[-1]) == False:
                rho_guess = rho_guess_grid[i]
            else:
                rho_guess = density_values[-1]
        dens, props_list = compute_density(P_target, T, rho_guess, T_s0, V_s0)
        if dens is not None:
            density_values.append(dens)
            entropy_values.append(props_list['entropy_mass'])
            alpha_values.append(props_list["thermal_expansion"])
            Eth_values.append(props_list["internal_energy_mass"])
            cP_values.append(props_list['Cp_mass'])
            cV_values.append(props_list['Cv_mass'])
            KT_values.append(props_list["bulk_modulus"])
        else:
            # If the EOS fails
            density_values.append(np.nan)
            entropy_values.append(np.nan)
            alpha_values.append(np.nan)
            Eth_values.append(np.nan)
            cP_values.append(np.nan)
            cV_values.append(np.nan)
            KT_values.append(np.nan)

    density_values = np.array(density_values)
    entropy_values = np.array(entropy_values)
    alpha_values = np.array(alpha_values)
    Eth_values = np.array(Eth_values)
    cV_values = np.array(cV_values)
    cP_values = np.array(cP_values)
    KT_values = np.array(KT_values)
    # Only use the temperatures where density was computed successfully for extrapolation.
    mask = np.isfinite(density_values)
    T_fit = T_values[mask]
    density_fit = density_values[mask]
    entropy_fit = entropy_values[mask]
    alpha_fit = alpha_values[mask]
    Eth_fit = Eth_values[mask]
    cV_fit = cV_values[mask]
    cP_fit = cP_values[mask]
    KT_fit = KT_values[mask]
    
    # save the amount of successful calculated densities for reference
    successful_rho[i] = len(T_fit)
    
    if len(density_fit) == len(density_values):
        # skip extrapolation if all values are computed successfully
        rho_table[i] = density_values.copy()
        Eth_table[i] = Eth_values.copy()
        alpha_table[i] = alpha_values.copy()
        cP_table[i] = cP_values.copy()
        cV_table[i] = cV_values.copy()
        s_table[i] = entropy_values.copy()
        KT_table[i] = KT_values.copy()
        print('P=',int(P_grid_GPa[i]),'GPa. extrapolation not needed. density:', int(rho_table[i][300]),'kg/m^3, entropy:',int(s_table[i][300]),'J/K/kg, internal energy:', int(Eth_table[i][300]/1e3),'kJ/kg')
    else:
        # perform extrapolation if not all TP levels return real density values
        if len(T_fit) < 2:
            raise ValueError("Not enough data points for extrapolation.")
        # Fit a spline (or use np.polyfit for a polynomial fit).
        # Here we choose a quadratic spline with no smoothing (s=0).
        spline = UnivariateSpline(T_fit, density_fit, k=2, s=0)
        rho_table[i] = spline(T_extrap)

        # For all other quantities
        spline = UnivariateSpline(T_fit, entropy_fit, k=2, s=0)
        s_table[i] = spline(T_extrap)

        spline = UnivariateSpline(T_fit, Eth_fit, k=2, s=0)
        Eth_table[i] = spline(T_extrap)

        spline = UnivariateSpline(T_fit, alpha_fit, k=2, s=0)
        alpha_table[i] = spline(T_extrap)

        spline = UnivariateSpline(T_fit, cV_fit, k=2, s=0)
        cP_table[i] = spline(T_extrap)

        spline = UnivariateSpline(T_fit, cP_fit, k=2, s=0)
        cV_table[i] = spline(T_extrap)

        spline = UnivariateSpline(T_fit, KT_fit, k=2, s=0)
        KT_table[i] = spline(T_extrap)
        
        print('P=',int(P_grid_GPa[i]),'GPa. extrapolation needed! density:', int(rho_table[i][300]),'kg/m^3, entropy:',int(s_table[i][300]),'J/K/kg, internal energy:', int(Eth_table[i][300]/1e3),'kJ/kg')
# Out:
# P= 0 GPa. extrapolation needed! density: -509874 kg/m^3, entropy: -579 J/K/kg, internal energy: -29678 kJ/kg
# P= 10 GPa. extrapolation not needed. density: 449 kg/m^3, entropy: 464 J/K/kg, internal energy: 8495 kJ/kg
# P= 20 GPa. extrapolation not needed. density: 1138 kg/m^3, entropy: 506 J/K/kg, internal energy: 9103 kJ/kg
# P= 30 GPa. extrapolation not needed. density: 1964 kg/m^3, entropy: 540 J/K/kg, internal energy: 9580 kJ/kg
# P= 40 GPa. extrapolation not needed. density: 2918 kg/m^3, entropy: 569 J/K/kg, internal energy: 9997 kJ/kg
# P= 50 GPa. extrapolation not needed. density: 3892 kg/m^3, entropy: 594 J/K/kg, internal energy: 10346 kJ/kg
# P= 60 GPa. extrapolation not needed. density: 4733 kg/m^3, entropy: 612 J/K/kg, internal energy: 10606 kJ/kg
# P= 70 GPa. extrapolation not needed. density: 5413 kg/m^3, entropy: 625 J/K/kg, internal energy: 10797 kJ/kg
# P= 80 GPa. extrapolation not needed. density: 5969 kg/m^3, entropy: 636 J/K/kg, internal energy: 10943 kJ/kg
# P= 90 GPa. extrapolation not needed. density: 6438 kg/m^3, entropy: 644 J/K/kg, internal energy: 11059 kJ/kg
# P= 100 GPa. extrapolation not needed. density: 6845 kg/m^3, entropy: 651 J/K/kg, internal energy: 11156 kJ/kg
# P= 110 GPa. extrapolation not needed. density: 7204 kg/m^3, entropy: 657 J/K/kg, internal energy: 11239 kJ/kg
# P= 120 GPa. extrapolation not needed. density: 7528 kg/m^3, entropy: 662 J/K/kg, internal energy: 11312 kJ/kg
# P= 130 GPa. extrapolation not needed. density: 7824 kg/m^3, entropy: 666 J/K/kg, internal energy: 11377 kJ/kg
# P= 140 GPa. extrapolation not needed. density: 8097 kg/m^3, entropy: 670 J/K/kg, internal energy: 11435 kJ/kg
# P= 150 GPa. extrapolation not needed. density: 8350 kg/m^3, entropy: 674 J/K/kg, internal energy: 11488 kJ/kg
# P= 160 GPa. extrapolation not needed. density: 8588 kg/m^3, entropy: 678 J/K/kg, internal energy: 11537 kJ/kg
# P= 170 GPa. extrapolation not needed. density: 8811 kg/m^3, entropy: 681 J/K/kg, internal energy: 11583 kJ/kg
# P= 180 GPa. extrapolation not needed. density: 9023 kg/m^3, entropy: 684 J/K/kg, internal energy: 11625 kJ/kg
# P= 190 GPa. extrapolation not needed. density: 9224 kg/m^3, entropy: 686 J/K/kg, internal energy: 11665 kJ/kg
# P= 200 GPa. extrapolation not needed. density: 9416 kg/m^3, entropy: 689 J/K/kg, internal energy: 11702 kJ/kg
# P= 210 GPa. extrapolation not needed. density: 9600 kg/m^3, entropy: 692 J/K/kg, internal energy: 11737 kJ/kg
# P= 220 GPa. extrapolation not needed. density: 9777 kg/m^3, entropy: 694 J/K/kg, internal energy: 11771 kJ/kg
# P= 230 GPa. extrapolation not needed. density: 9947 kg/m^3, entropy: 696 J/K/kg, internal energy: 11803 kJ/kg
# P= 240 GPa. extrapolation not needed. density: 10110 kg/m^3, entropy: 698 J/K/kg, internal energy: 11834 kJ/kg
# P= 250 GPa. extrapolation not needed. density: 10269 kg/m^3, entropy: 700 J/K/kg, internal energy: 11863 kJ/kg
# P= 260 GPa. extrapolation not needed. density: 10422 kg/m^3, entropy: 702 J/K/kg, internal energy: 11891 kJ/kg
# P= 270 GPa. extrapolation not needed. density: 10570 kg/m^3, entropy: 704 J/K/kg, internal energy: 11918 kJ/kg
# P= 280 GPa. extrapolation not needed. density: 10715 kg/m^3, entropy: 706 J/K/kg, internal energy: 11944 kJ/kg
# P= 290 GPa. extrapolation not needed. density: 10855 kg/m^3, entropy: 708 J/K/kg, internal energy: 11969 kJ/kg
# P= 300 GPa. extrapolation not needed. density: 10992 kg/m^3, entropy: 710 J/K/kg, internal energy: 11993 kJ/kg
# P= 310 GPa. extrapolation not needed. density: 11125 kg/m^3, entropy: 711 J/K/kg, internal energy: 12016 kJ/kg
# P= 320 GPa. extrapolation not needed. density: 11255 kg/m^3, entropy: 713 J/K/kg, internal energy: 12039 kJ/kg
# P= 330 GPa. extrapolation not needed. density: 11381 kg/m^3, entropy: 714 J/K/kg, internal energy: 12061 kJ/kg
# P= 340 GPa. extrapolation not needed. density: 11505 kg/m^3, entropy: 716 J/K/kg, internal energy: 12082 kJ/kg
# P= 350 GPa. extrapolation not needed. density: 11627 kg/m^3, entropy: 717 J/K/kg, internal energy: 12103 kJ/kg
# P= 360 GPa. extrapolation not needed. density: 11745 kg/m^3, entropy: 719 J/K/kg, internal energy: 12123 kJ/kg
# P= 370 GPa. extrapolation not needed. density: 11862 kg/m^3, entropy: 720 J/K/kg, internal energy: 12143 kJ/kg
# P= 380 GPa. extrapolation not needed. density: 11976 kg/m^3, entropy: 721 J/K/kg, internal energy: 12162 kJ/kg
# P= 390 GPa. extrapolation not needed. density: 12088 kg/m^3, entropy: 723 J/K/kg, internal energy: 12181 kJ/kg
# P= 400 GPa. extrapolation not needed. density: 12197 kg/m^3, entropy: 724 J/K/kg, internal energy: 12199 kJ/kg
# P= 410 GPa. extrapolation not needed. density: 12305 kg/m^3, entropy: 725 J/K/kg, internal energy: 12217 kJ/kg
# P= 420 GPa. extrapolation not needed. density: 12411 kg/m^3, entropy: 727 J/K/kg, internal energy: 12234 kJ/kg
# P= 430 GPa. extrapolation not needed. density: 12515 kg/m^3, entropy: 728 J/K/kg, internal energy: 12251 kJ/kg
# P= 440 GPa. extrapolation not needed. density: 12618 kg/m^3, entropy: 729 J/K/kg, internal energy: 12268 kJ/kg
# P= 450 GPa. extrapolation not needed. density: 12719 kg/m^3, entropy: 730 J/K/kg, internal energy: 12284 kJ/kg
# P= 460 GPa. extrapolation not needed. density: 12818 kg/m^3, entropy: 731 J/K/kg, internal energy: 12300 kJ/kg
# P= 470 GPa. extrapolation not needed. density: 12916 kg/m^3, entropy: 732 J/K/kg, internal energy: 12316 kJ/kg
# P= 480 GPa. extrapolation not needed. density: 13012 kg/m^3, entropy: 733 J/K/kg, internal energy: 12331 kJ/kg
# P= 490 GPa. extrapolation not needed. density: 13107 kg/m^3, entropy: 734 J/K/kg, internal energy: 12347 kJ/kg
# P= 500 GPa. extrapolation not needed. density: 13201 kg/m^3, entropy: 735 J/K/kg, internal energy: 12361 kJ/kg
# P= 510 GPa. extrapolation not needed. density: 13293 kg/m^3, entropy: 736 J/K/kg, internal energy: 12376 kJ/kg
# P= 520 GPa. extrapolation not needed. density: 13385 kg/m^3, entropy: 737 J/K/kg, internal energy: 12390 kJ/kg
# P= 530 GPa. extrapolation not needed. density: 13475 kg/m^3, entropy: 738 J/K/kg, internal energy: 12404 kJ/kg
# P= 540 GPa. extrapolation not needed. density: 13563 kg/m^3, entropy: 739 J/K/kg, internal energy: 12418 kJ/kg
# P= 550 GPa. extrapolation not needed. density: 13651 kg/m^3, entropy: 740 J/K/kg, internal energy: 12432 kJ/kg
# P= 560 GPa. extrapolation not needed. density: 13738 kg/m^3, entropy: 741 J/K/kg, internal energy: 12445 kJ/kg
# P= 570 GPa. extrapolation not needed. density: 13823 kg/m^3, entropy: 742 J/K/kg, internal energy: 12458 kJ/kg
# P= 580 GPa. extrapolation not needed. density: 13908 kg/m^3, entropy: 743 J/K/kg, internal energy: 12471 kJ/kg
# P= 590 GPa. extrapolation not needed. density: 13992 kg/m^3, entropy: 744 J/K/kg, internal energy: 12484 kJ/kg
# P= 600 GPa. extrapolation not needed. density: 14074 kg/m^3, entropy: 745 J/K/kg, internal energy: 12497 kJ/kg
# P= 610 GPa. extrapolation not needed. density: 14156 kg/m^3, entropy: 746 J/K/kg, internal energy: 12509 kJ/kg
# P= 620 GPa. extrapolation not needed. density: 14237 kg/m^3, entropy: 747 J/K/kg, internal energy: 12521 kJ/kg
# P= 630 GPa. extrapolation not needed. density: 14317 kg/m^3, entropy: 748 J/K/kg, internal energy: 12533 kJ/kg
# P= 640 GPa. extrapolation not needed. density: 14396 kg/m^3, entropy: 748 J/K/kg, internal energy: 12545 kJ/kg
# P= 650 GPa. extrapolation not needed. density: 14475 kg/m^3, entropy: 749 J/K/kg, internal energy: 12557 kJ/kg
# P= 660 GPa. extrapolation not needed. density: 14552 kg/m^3, entropy: 750 J/K/kg, internal energy: 12569 kJ/kg
# P= 670 GPa. extrapolation not needed. density: 14629 kg/m^3, entropy: 751 J/K/kg, internal energy: 12580 kJ/kg
# P= 680 GPa. extrapolation not needed. density: 14705 kg/m^3, entropy: 752 J/K/kg, internal energy: 12591 kJ/kg
# P= 690 GPa. extrapolation not needed. density: 14781 kg/m^3, entropy: 752 J/K/kg, internal energy: 12603 kJ/kg
# P= 700 GPa. extrapolation not needed. density: 14855 kg/m^3, entropy: 753 J/K/kg, internal energy: 12614 kJ/kg
# P= 710 GPa. extrapolation not needed. density: 14929 kg/m^3, entropy: 754 J/K/kg, internal energy: 12624 kJ/kg
# P= 720 GPa. extrapolation not needed. density: 15002 kg/m^3, entropy: 755 J/K/kg, internal energy: 12635 kJ/kg
# P= 730 GPa. extrapolation not needed. density: 15075 kg/m^3, entropy: 755 J/K/kg, internal energy: 12646 kJ/kg
# P= 740 GPa. extrapolation not needed. density: 15147 kg/m^3, entropy: 756 J/K/kg, internal energy: 12656 kJ/kg
# P= 750 GPa. extrapolation not needed. density: 15218 kg/m^3, entropy: 757 J/K/kg, internal energy: 12667 kJ/kg
# P= 760 GPa. extrapolation not needed. density: 15289 kg/m^3, entropy: 758 J/K/kg, internal energy: 12677 kJ/kg
# P= 770 GPa. extrapolation not needed. density: 15359 kg/m^3, entropy: 758 J/K/kg, internal energy: 12687 kJ/kg
# P= 780 GPa. extrapolation not needed. density: 15429 kg/m^3, entropy: 759 J/K/kg, internal energy: 12697 kJ/kg
# P= 790 GPa. extrapolation not needed. density: 15498 kg/m^3, entropy: 760 J/K/kg, internal energy: 12707 kJ/kg
# P= 800 GPa. extrapolation not needed. density: 15567 kg/m^3, entropy: 760 J/K/kg, internal energy: 12717 kJ/kg
# P= 810 GPa. extrapolation not needed. density: 15634 kg/m^3, entropy: 761 J/K/kg, internal energy: 12727 kJ/kg
# P= 820 GPa. extrapolation not needed. density: 15702 kg/m^3, entropy: 762 J/K/kg, internal energy: 12736 kJ/kg
# P= 830 GPa. extrapolation not needed. density: 15769 kg/m^3, entropy: 762 J/K/kg, internal energy: 12746 kJ/kg
# P= 840 GPa. extrapolation not needed. density: 15835 kg/m^3, entropy: 763 J/K/kg, internal energy: 12755 kJ/kg
# P= 850 GPa. extrapolation not needed. density: 15901 kg/m^3, entropy: 764 J/K/kg, internal energy: 12764 kJ/kg
# P= 860 GPa. extrapolation not needed. density: 15966 kg/m^3, entropy: 764 J/K/kg, internal energy: 12774 kJ/kg
# P= 870 GPa. extrapolation not needed. density: 16031 kg/m^3, entropy: 765 J/K/kg, internal energy: 12783 kJ/kg
# P= 880 GPa. extrapolation not needed. density: 16096 kg/m^3, entropy: 766 J/K/kg, internal energy: 12792 kJ/kg
# P= 890 GPa. extrapolation not needed. density: 16160 kg/m^3, entropy: 766 J/K/kg, internal energy: 12801 kJ/kg
# P= 900 GPa. extrapolation not needed. density: 16223 kg/m^3, entropy: 767 J/K/kg, internal energy: 12810 kJ/kg
# P= 910 GPa. extrapolation not needed. density: 16286 kg/m^3, entropy: 768 J/K/kg, internal energy: 12819 kJ/kg
# P= 920 GPa. extrapolation not needed. density: 16349 kg/m^3, entropy: 768 J/K/kg, internal energy: 12827 kJ/kg
# P= 930 GPa. extrapolation not needed. density: 16411 kg/m^3, entropy: 769 J/K/kg, internal energy: 12836 kJ/kg
# P= 940 GPa. extrapolation not needed. density: 16473 kg/m^3, entropy: 769 J/K/kg, internal energy: 12844 kJ/kg
# P= 950 GPa. extrapolation not needed. density: 16535 kg/m^3, entropy: 770 J/K/kg, internal energy: 12853 kJ/kg
# P= 960 GPa. extrapolation not needed. density: 16596 kg/m^3, entropy: 771 J/K/kg, internal energy: 12861 kJ/kg
# P= 970 GPa. extrapolation not needed. density: 16656 kg/m^3, entropy: 771 J/K/kg, internal energy: 12870 kJ/kg
# P= 980 GPa. extrapolation not needed. density: 16716 kg/m^3, entropy: 772 J/K/kg, internal energy: 12878 kJ/kg
# P= 990 GPa. extrapolation not needed. density: 16776 kg/m^3, entropy: 772 J/K/kg, internal energy: 12886 kJ/kg
# P= 1000 GPa. extrapolation not needed. density: 16836 kg/m^3, entropy: 773 J/K/kg, internal energy: 12894 kJ/kg
# P= 1010 GPa. extrapolation not needed. density: 16895 kg/m^3, entropy: 773 J/K/kg, internal energy: 12902 kJ/kg
# P= 1020 GPa. extrapolation not needed. density: 16954 kg/m^3, entropy: 774 J/K/kg, internal energy: 12910 kJ/kg
# P= 1030 GPa. extrapolation not needed. density: 17012 kg/m^3, entropy: 775 J/K/kg, internal energy: 12918 kJ/kg
# P= 1040 GPa. extrapolation not needed. density: 17070 kg/m^3, entropy: 775 J/K/kg, internal energy: 12926 kJ/kg
# P= 1050 GPa. extrapolation not needed. density: 17128 kg/m^3, entropy: 776 J/K/kg, internal energy: 12934 kJ/kg
# P= 1060 GPa. extrapolation not needed. density: 17185 kg/m^3, entropy: 776 J/K/kg, internal energy: 12942 kJ/kg
# P= 1070 GPa. extrapolation not needed. density: 17242 kg/m^3, entropy: 777 J/K/kg, internal energy: 12949 kJ/kg
# P= 1080 GPa. extrapolation not needed. density: 17299 kg/m^3, entropy: 777 J/K/kg, internal energy: 12957 kJ/kg
# P= 1090 GPa. extrapolation not needed. density: 17355 kg/m^3, entropy: 778 J/K/kg, internal energy: 12965 kJ/kg
# P= 1100 GPa. extrapolation not needed. density: 17412 kg/m^3, entropy: 778 J/K/kg, internal energy: 12972 kJ/kg
# P= 1110 GPa. extrapolation not needed. density: 17467 kg/m^3, entropy: 779 J/K/kg, internal energy: 12980 kJ/kg
# P= 1120 GPa. extrapolation not needed. density: 17523 kg/m^3, entropy: 779 J/K/kg, internal energy: 12987 kJ/kg
# P= 1130 GPa. extrapolation not needed. density: 17578 kg/m^3, entropy: 780 J/K/kg, internal energy: 12994 kJ/kg
# P= 1140 GPa. extrapolation not needed. density: 17633 kg/m^3, entropy: 780 J/K/kg, internal energy: 13002 kJ/kg
# P= 1150 GPa. extrapolation not needed. density: 17688 kg/m^3, entropy: 781 J/K/kg, internal energy: 13009 kJ/kg
# P= 1160 GPa. extrapolation not needed. density: 17742 kg/m^3, entropy: 781 J/K/kg, internal energy: 13016 kJ/kg
# P= 1170 GPa. extrapolation not needed. density: 17796 kg/m^3, entropy: 782 J/K/kg, internal energy: 13023 kJ/kg
# P= 1180 GPa. extrapolation not needed. density: 17850 kg/m^3, entropy: 782 J/K/kg, internal energy: 13030 kJ/kg
# P= 1190 GPa. extrapolation not needed. density: 17903 kg/m^3, entropy: 783 J/K/kg, internal energy: 13037 kJ/kg
# P= 1200 GPa. extrapolation not needed. density: 17956 kg/m^3, entropy: 783 J/K/kg, internal energy: 13044 kJ/kg
# P= 1210 GPa. extrapolation not needed. density: 18009 kg/m^3, entropy: 784 J/K/kg, internal energy: 13051 kJ/kg
# P= 1220 GPa. extrapolation not needed. density: 18062 kg/m^3, entropy: 784 J/K/kg, internal energy: 13058 kJ/kg
# P= 1230 GPa. extrapolation not needed. density: 18114 kg/m^3, entropy: 785 J/K/kg, internal energy: 13065 kJ/kg
# P= 1240 GPa. extrapolation not needed. density: 18166 kg/m^3, entropy: 785 J/K/kg, internal energy: 13072 kJ/kg
# P= 1250 GPa. extrapolation not needed. density: 18218 kg/m^3, entropy: 786 J/K/kg, internal energy: 13079 kJ/kg
# P= 1260 GPa. extrapolation not needed. density: 18270 kg/m^3, entropy: 786 J/K/kg, internal energy: 13085 kJ/kg
# P= 1270 GPa. extrapolation not needed. density: 18321 kg/m^3, entropy: 787 J/K/kg, internal energy: 13092 kJ/kg
# P= 1280 GPa. extrapolation not needed. density: 18373 kg/m^3, entropy: 787 J/K/kg, internal energy: 13099 kJ/kg
# P= 1290 GPa. extrapolation not needed. density: 18424 kg/m^3, entropy: 788 J/K/kg, internal energy: 13105 kJ/kg
# P= 1300 GPa. extrapolation not needed. density: 18474 kg/m^3, entropy: 788 J/K/kg, internal energy: 13112 kJ/kg
# P= 1310 GPa. extrapolation not needed. density: 18525 kg/m^3, entropy: 789 J/K/kg, internal energy: 13118 kJ/kg
# P= 1320 GPa. extrapolation not needed. density: 18575 kg/m^3, entropy: 789 J/K/kg, internal energy: 13125 kJ/kg
# P= 1330 GPa. extrapolation not needed. density: 18625 kg/m^3, entropy: 790 J/K/kg, internal energy: 13131 kJ/kg
# P= 1340 GPa. extrapolation not needed. density: 18675 kg/m^3, entropy: 790 J/K/kg, internal energy: 13138 kJ/kg
# P= 1350 GPa. extrapolation not needed. density: 18724 kg/m^3, entropy: 790 J/K/kg, internal energy: 13144 kJ/kg
# P= 1360 GPa. extrapolation not needed. density: 18774 kg/m^3, entropy: 791 J/K/kg, internal energy: 13150 kJ/kg
# P= 1370 GPa. extrapolation not needed. density: 18823 kg/m^3, entropy: 791 J/K/kg, internal energy: 13157 kJ/kg
# P= 1380 GPa. extrapolation not needed. density: 18872 kg/m^3, entropy: 792 J/K/kg, internal energy: 13163 kJ/kg
# P= 1390 GPa. extrapolation not needed. density: 18921 kg/m^3, entropy: 792 J/K/kg, internal energy: 13169 kJ/kg
# P= 1400 GPa. extrapolation not needed. density: 18969 kg/m^3, entropy: 793 J/K/kg, internal energy: 13175 kJ/kg
# P= 1410 GPa. extrapolation not needed. density: 19017 kg/m^3, entropy: 793 J/K/kg, internal energy: 13181 kJ/kg
# P= 1420 GPa. extrapolation not needed. density: 19065 kg/m^3, entropy: 794 J/K/kg, internal energy: 13188 kJ/kg
# P= 1430 GPa. extrapolation not needed. density: 19113 kg/m^3, entropy: 794 J/K/kg, internal energy: 13194 kJ/kg
# P= 1440 GPa. extrapolation not needed. density: 19161 kg/m^3, entropy: 794 J/K/kg, internal energy: 13200 kJ/kg
# P= 1450 GPa. extrapolation not needed. density: 19209 kg/m^3, entropy: 795 J/K/kg, internal energy: 13206 kJ/kg
# P= 1460 GPa. extrapolation not needed. density: 19256 kg/m^3, entropy: 795 J/K/kg, internal energy: 13212 kJ/kg
# P= 1470 GPa. extrapolation not needed. density: 19303 kg/m^3, entropy: 796 J/K/kg, internal energy: 13218 kJ/kg
# P= 1480 GPa. extrapolation not needed. density: 19350 kg/m^3, entropy: 796 J/K/kg, internal energy: 13223 kJ/kg
# P= 1490 GPa. extrapolation not needed. density: 19397 kg/m^3, entropy: 796 J/K/kg, internal energy: 13229 kJ/kg
# P= 1500 GPa. extrapolation not needed. density: 19443 kg/m^3, entropy: 797 J/K/kg, internal energy: 13235 kJ/kg
# P= 1510 GPa. extrapolation not needed. density: 19490 kg/m^3, entropy: 797 J/K/kg, internal energy: 13241 kJ/kg
# P= 1520 GPa. extrapolation not needed. density: 19536 kg/m^3, entropy: 798 J/K/kg, internal energy: 13247 kJ/kg
# P= 1530 GPa. extrapolation not needed. density: 19582 kg/m^3, entropy: 798 J/K/kg, internal energy: 13252 kJ/kg
# P= 1540 GPa. extrapolation not needed. density: 19628 kg/m^3, entropy: 799 J/K/kg, internal energy: 13258 kJ/kg
# P= 1550 GPa. extrapolation not needed. density: 19674 kg/m^3, entropy: 799 J/K/kg, internal energy: 13264 kJ/kg
# P= 1560 GPa. extrapolation not needed. density: 19719 kg/m^3, entropy: 799 J/K/kg, internal energy: 13270 kJ/kg
# P= 1570 GPa. extrapolation not needed. density: 19764 kg/m^3, entropy: 800 J/K/kg, internal energy: 13275 kJ/kg
# P= 1580 GPa. extrapolation not needed. density: 19810 kg/m^3, entropy: 800 J/K/kg, internal energy: 13281 kJ/kg
# P= 1590 GPa. extrapolation not needed. density: 19855 kg/m^3, entropy: 800 J/K/kg, internal energy: 13286 kJ/kg
# P= 1600 GPa. extrapolation not needed. density: 19899 kg/m^3, entropy: 801 J/K/kg, internal energy: 13292 kJ/kg
# P= 1610 GPa. extrapolation not needed. density: 19944 kg/m^3, entropy: 801 J/K/kg, internal energy: 13297 kJ/kg
# P= 1620 GPa. extrapolation not needed. density: 19989 kg/m^3, entropy: 802 J/K/kg, internal energy: 13303 kJ/kg
# P= 1630 GPa. extrapolation not needed. density: 20033 kg/m^3, entropy: 802 J/K/kg, internal energy: 13308 kJ/kg
# P= 1640 GPa. extrapolation not needed. density: 20077 kg/m^3, entropy: 802 J/K/kg, internal energy: 13314 kJ/kg
# P= 1650 GPa. extrapolation not needed. density: 20121 kg/m^3, entropy: 803 J/K/kg, internal energy: 13319 kJ/kg
# P= 1660 GPa. extrapolation not needed. density: 20165 kg/m^3, entropy: 803 J/K/kg, internal energy: 13325 kJ/kg
# P= 1670 GPa. extrapolation not needed. density: 20209 kg/m^3, entropy: 804 J/K/kg, internal energy: 13330 kJ/kg
# P= 1680 GPa. extrapolation not needed. density: 20253 kg/m^3, entropy: 804 J/K/kg, internal energy: 13335 kJ/kg
# P= 1690 GPa. extrapolation not needed. density: 20296 kg/m^3, entropy: 804 J/K/kg, internal energy: 13341 kJ/kg
# P= 1700 GPa. extrapolation not needed. density: 20339 kg/m^3, entropy: 805 J/K/kg, internal energy: 13346 kJ/kg
# P= 1710 GPa. extrapolation not needed. density: 20382 kg/m^3, entropy: 805 J/K/kg, internal energy: 13351 kJ/kg
# P= 1720 GPa. extrapolation not needed. density: 20425 kg/m^3, entropy: 805 J/K/kg, internal energy: 13356 kJ/kg
# P= 1730 GPa. extrapolation not needed. density: 20468 kg/m^3, entropy: 806 J/K/kg, internal energy: 13362 kJ/kg
# P= 1740 GPa. extrapolation not needed. density: 20511 kg/m^3, entropy: 806 J/K/kg, internal energy: 13367 kJ/kg
# P= 1750 GPa. extrapolation not needed. density: 20554 kg/m^3, entropy: 807 J/K/kg, internal energy: 13372 kJ/kg
# P= 1760 GPa. extrapolation not needed. density: 20596 kg/m^3, entropy: 807 J/K/kg, internal energy: 13377 kJ/kg
# P= 1770 GPa. extrapolation not needed. density: 20638 kg/m^3, entropy: 807 J/K/kg, internal energy: 13382 kJ/kg
# P= 1780 GPa. extrapolation not needed. density: 20680 kg/m^3, entropy: 808 J/K/kg, internal energy: 13387 kJ/kg
# P= 1790 GPa. extrapolation not needed. density: 20723 kg/m^3, entropy: 808 J/K/kg, internal energy: 13392 kJ/kg
# P= 1800 GPa. extrapolation not needed. density: 20764 kg/m^3, entropy: 808 J/K/kg, internal energy: 13397 kJ/kg
# P= 1810 GPa. extrapolation not needed. density: 20806 kg/m^3, entropy: 809 J/K/kg, internal energy: 13402 kJ/kg
# P= 1820 GPa. extrapolation not needed. density: 20848 kg/m^3, entropy: 809 J/K/kg, internal energy: 13407 kJ/kg
# P= 1830 GPa. extrapolation not needed. density: 20889 kg/m^3, entropy: 809 J/K/kg, internal energy: 13412 kJ/kg
# P= 1840 GPa. extrapolation not needed. density: 20931 kg/m^3, entropy: 810 J/K/kg, internal energy: 13417 kJ/kg
# P= 1850 GPa. extrapolation not needed. density: 20972 kg/m^3, entropy: 810 J/K/kg, internal energy: 13422 kJ/kg
# P= 1860 GPa. extrapolation not needed. density: 21013 kg/m^3, entropy: 810 J/K/kg, internal energy: 13427 kJ/kg
# P= 1870 GPa. extrapolation not needed. density: 21054 kg/m^3, entropy: 811 J/K/kg, internal energy: 13432 kJ/kg
# P= 1880 GPa. extrapolation not needed. density: 21095 kg/m^3, entropy: 811 J/K/kg, internal energy: 13437 kJ/kg
# P= 1890 GPa. extrapolation not needed. density: 21136 kg/m^3, entropy: 811 J/K/kg, internal energy: 13442 kJ/kg
# P= 1900 GPa. extrapolation not needed. density: 21176 kg/m^3, entropy: 812 J/K/kg, internal energy: 13447 kJ/kg
# P= 1910 GPa. extrapolation not needed. density: 21217 kg/m^3, entropy: 812 J/K/kg, internal energy: 13451 kJ/kg
# P= 1920 GPa. extrapolation not needed. density: 21257 kg/m^3, entropy: 812 J/K/kg, internal energy: 13456 kJ/kg
# P= 1930 GPa. extrapolation not needed. density: 21297 kg/m^3, entropy: 813 J/K/kg, internal energy: 13461 kJ/kg
# P= 1940 GPa. extrapolation not needed. density: 21337 kg/m^3, entropy: 813 J/K/kg, internal energy: 13466 kJ/kg
# P= 1950 GPa. extrapolation not needed. density: 21377 kg/m^3, entropy: 813 J/K/kg, internal energy: 13471 kJ/kg
# P= 1960 GPa. extrapolation not needed. density: 21417 kg/m^3, entropy: 814 J/K/kg, internal energy: 13475 kJ/kg
# P= 1970 GPa. extrapolation not needed. density: 21457 kg/m^3, entropy: 814 J/K/kg, internal energy: 13480 kJ/kg
# P= 1980 GPa. extrapolation not needed. density: 21497 kg/m^3, entropy: 814 J/K/kg, internal energy: 13485 kJ/kg
# P= 1990 GPa. extrapolation not needed. density: 21536 kg/m^3, entropy: 815 J/K/kg, internal energy: 13489 kJ/kg
# P= 2000 GPa. extrapolation not needed. density: 21576 kg/m^3, entropy: 815 J/K/kg, internal energy: 13494 kJ/kg
# P= 2010 GPa. extrapolation not needed. density: 21615 kg/m^3, entropy: 815 J/K/kg, internal energy: 13499 kJ/kg
# P= 2020 GPa. extrapolation not needed. density: 21654 kg/m^3, entropy: 816 J/K/kg, internal energy: 13503 kJ/kg
# P= 2030 GPa. extrapolation not needed. density: 21693 kg/m^3, entropy: 816 J/K/kg, internal energy: 13508 kJ/kg
# P= 2040 GPa. extrapolation not needed. density: 21732 kg/m^3, entropy: 816 J/K/kg, internal energy: 13512 kJ/kg
# P= 2050 GPa. extrapolation not needed. density: 21771 kg/m^3, entropy: 817 J/K/kg, internal energy: 13517 kJ/kg
# P= 2060 GPa. extrapolation not needed. density: 21810 kg/m^3, entropy: 817 J/K/kg, internal energy: 13521 kJ/kg
# P= 2070 GPa. extrapolation not needed. density: 21849 kg/m^3, entropy: 817 J/K/kg, internal energy: 13526 kJ/kg
# P= 2080 GPa. extrapolation not needed. density: 21887 kg/m^3, entropy: 818 J/K/kg, internal energy: 13530 kJ/kg
# P= 2090 GPa. extrapolation not needed. density: 21926 kg/m^3, entropy: 818 J/K/kg, internal energy: 13535 kJ/kg
# P= 2100 GPa. extrapolation not needed. density: 21964 kg/m^3, entropy: 818 J/K/kg, internal energy: 13539 kJ/kg
# P= 2110 GPa. extrapolation not needed. density: 22003 kg/m^3, entropy: 819 J/K/kg, internal energy: 13544 kJ/kg
# P= 2120 GPa. extrapolation not needed. density: 22041 kg/m^3, entropy: 819 J/K/kg, internal energy: 13548 kJ/kg
# P= 2130 GPa. extrapolation not needed. density: 22079 kg/m^3, entropy: 819 J/K/kg, internal energy: 13553 kJ/kg
# P= 2140 GPa. extrapolation not needed. density: 22117 kg/m^3, entropy: 820 J/K/kg, internal energy: 13557 kJ/kg
# P= 2150 GPa. extrapolation not needed. density: 22155 kg/m^3, entropy: 820 J/K/kg, internal energy: 13562 kJ/kg
# P= 2160 GPa. extrapolation not needed. density: 22192 kg/m^3, entropy: 820 J/K/kg, internal energy: 13566 kJ/kg
# P= 2170 GPa. extrapolation not needed. density: 22230 kg/m^3, entropy: 820 J/K/kg, internal energy: 13570 kJ/kg
# P= 2180 GPa. extrapolation not needed. density: 22268 kg/m^3, entropy: 821 J/K/kg, internal energy: 13575 kJ/kg
# P= 2190 GPa. extrapolation not needed. density: 22305 kg/m^3, entropy: 821 J/K/kg, internal energy: 13579 kJ/kg
# P= 2200 GPa. extrapolation not needed. density: 22342 kg/m^3, entropy: 821 J/K/kg, internal energy: 13583 kJ/kg
# P= 2210 GPa. extrapolation not needed. density: 22380 kg/m^3, entropy: 822 J/K/kg, internal energy: 13588 kJ/kg
# P= 2220 GPa. extrapolation not needed. density: 22417 kg/m^3, entropy: 822 J/K/kg, internal energy: 13592 kJ/kg
# P= 2230 GPa. extrapolation not needed. density: 22454 kg/m^3, entropy: 822 J/K/kg, internal energy: 13596 kJ/kg
# P= 2240 GPa. extrapolation not needed. density: 22491 kg/m^3, entropy: 823 J/K/kg, internal energy: 13600 kJ/kg
# P= 2250 GPa. extrapolation not needed. density: 22528 kg/m^3, entropy: 823 J/K/kg, internal energy: 13605 kJ/kg
# P= 2260 GPa. extrapolation not needed. density: 22565 kg/m^3, entropy: 823 J/K/kg, internal energy: 13609 kJ/kg
# P= 2270 GPa. extrapolation not needed. density: 22601 kg/m^3, entropy: 823 J/K/kg, internal energy: 13613 kJ/kg
# P= 2280 GPa. extrapolation not needed. density: 22638 kg/m^3, entropy: 824 J/K/kg, internal energy: 13617 kJ/kg
# P= 2290 GPa. extrapolation not needed. density: 22675 kg/m^3, entropy: 824 J/K/kg, internal energy: 13621 kJ/kg
# P= 2300 GPa. extrapolation not needed. density: 22711 kg/m^3, entropy: 824 J/K/kg, internal energy: 13626 kJ/kg
# P= 2310 GPa. extrapolation not needed. density: 22747 kg/m^3, entropy: 825 J/K/kg, internal energy: 13630 kJ/kg
# P= 2320 GPa. extrapolation not needed. density: 22784 kg/m^3, entropy: 825 J/K/kg, internal energy: 13634 kJ/kg
# P= 2330 GPa. extrapolation not needed. density: 22820 kg/m^3, entropy: 825 J/K/kg, internal energy: 13638 kJ/kg
# P= 2340 GPa. extrapolation not needed. density: 22856 kg/m^3, entropy: 826 J/K/kg, internal energy: 13642 kJ/kg
# P= 2350 GPa. extrapolation not needed. density: 22892 kg/m^3, entropy: 826 J/K/kg, internal energy: 13646 kJ/kg
# P= 2360 GPa. extrapolation not needed. density: 22928 kg/m^3, entropy: 826 J/K/kg, internal energy: 13650 kJ/kg
# P= 2370 GPa. extrapolation not needed. density: 22964 kg/m^3, entropy: 826 J/K/kg, internal energy: 13654 kJ/kg
# P= 2380 GPa. extrapolation not needed. density: 23000 kg/m^3, entropy: 827 J/K/kg, internal energy: 13658 kJ/kg
# P= 2390 GPa. extrapolation not needed. density: 23035 kg/m^3, entropy: 827 J/K/kg, internal energy: 13662 kJ/kg
# P= 2400 GPa. extrapolation not needed. density: 23071 kg/m^3, entropy: 827 J/K/kg, internal energy: 13666 kJ/kg
# P= 2410 GPa. extrapolation not needed. density: 23106 kg/m^3, entropy: 827 J/K/kg, internal energy: 13670 kJ/kg
# P= 2420 GPa. extrapolation not needed. density: 23142 kg/m^3, entropy: 828 J/K/kg, internal energy: 13674 kJ/kg
# P= 2430 GPa. extrapolation not needed. density: 23177 kg/m^3, entropy: 828 J/K/kg, internal energy: 13678 kJ/kg
# P= 2440 GPa. extrapolation not needed. density: 23212 kg/m^3, entropy: 828 J/K/kg, internal energy: 13682 kJ/kg
# P= 2450 GPa. extrapolation not needed. density: 23248 kg/m^3, entropy: 829 J/K/kg, internal energy: 13686 kJ/kg
# P= 2460 GPa. extrapolation not needed. density: 23283 kg/m^3, entropy: 829 J/K/kg, internal energy: 13690 kJ/kg
# P= 2470 GPa. extrapolation not needed. density: 23318 kg/m^3, entropy: 829 J/K/kg, internal energy: 13694 kJ/kg
# P= 2480 GPa. extrapolation not needed. density: 23353 kg/m^3, entropy: 829 J/K/kg, internal energy: 13698 kJ/kg
# P= 2490 GPa. extrapolation not needed. density: 23388 kg/m^3, entropy: 830 J/K/kg, internal energy: 13702 kJ/kg
# P= 2500 GPa. extrapolation not needed. density: 23422 kg/m^3, entropy: 830 J/K/kg, internal energy: 13706 kJ/kg
# P= 2510 GPa. extrapolation not needed. density: 23457 kg/m^3, entropy: 830 J/K/kg, internal energy: 13710 kJ/kg
# P= 2520 GPa. extrapolation not needed. density: 23492 kg/m^3, entropy: 831 J/K/kg, internal energy: 13714 kJ/kg
# P= 2530 GPa. extrapolation not needed. density: 23526 kg/m^3, entropy: 831 J/K/kg, internal energy: 13718 kJ/kg
# P= 2540 GPa. extrapolation not needed. density: 23561 kg/m^3, entropy: 831 J/K/kg, internal energy: 13721 kJ/kg
# P= 2550 GPa. extrapolation not needed. density: 23595 kg/m^3, entropy: 831 J/K/kg, internal energy: 13725 kJ/kg
# P= 2560 GPa. extrapolation not needed. density: 23630 kg/m^3, entropy: 832 J/K/kg, internal energy: 13729 kJ/kg
# P= 2570 GPa. extrapolation not needed. density: 23664 kg/m^3, entropy: 832 J/K/kg, internal energy: 13733 kJ/kg
# P= 2580 GPa. extrapolation not needed. density: 23698 kg/m^3, entropy: 832 J/K/kg, internal energy: 13737 kJ/kg
# P= 2590 GPa. extrapolation not needed. density: 23732 kg/m^3, entropy: 832 J/K/kg, internal energy: 13741 kJ/kg
# P= 2600 GPa. extrapolation not needed. density: 23766 kg/m^3, entropy: 833 J/K/kg, internal energy: 13744 kJ/kg
# P= 2610 GPa. extrapolation not needed. density: 23800 kg/m^3, entropy: 833 J/K/kg, internal energy: 13748 kJ/kg
# P= 2620 GPa. extrapolation not needed. density: 23834 kg/m^3, entropy: 833 J/K/kg, internal energy: 13752 kJ/kg
# P= 2630 GPa. extrapolation not needed. density: 23868 kg/m^3, entropy: 833 J/K/kg, internal energy: 13756 kJ/kg
# P= 2640 GPa. extrapolation not needed. density: 23902 kg/m^3, entropy: 834 J/K/kg, internal energy: 13759 kJ/kg
# P= 2650 GPa. extrapolation not needed. density: 23935 kg/m^3, entropy: 834 J/K/kg, internal energy: 13763 kJ/kg
# P= 2660 GPa. extrapolation not needed. density: 23969 kg/m^3, entropy: 834 J/K/kg, internal energy: 13767 kJ/kg
# P= 2670 GPa. extrapolation not needed. density: 24003 kg/m^3, entropy: 835 J/K/kg, internal energy: 13770 kJ/kg
# P= 2680 GPa. extrapolation not needed. density: 24036 kg/m^3, entropy: 835 J/K/kg, internal energy: 13774 kJ/kg
# P= 2690 GPa. extrapolation not needed. density: 24070 kg/m^3, entropy: 835 J/K/kg, internal energy: 13778 kJ/kg
# P= 2700 GPa. extrapolation not needed. density: 24103 kg/m^3, entropy: 835 J/K/kg, internal energy: 13782 kJ/kg
# P= 2710 GPa. extrapolation not needed. density: 24136 kg/m^3, entropy: 836 J/K/kg, internal energy: 13785 kJ/kg
# P= 2720 GPa. extrapolation not needed. density: 24169 kg/m^3, entropy: 836 J/K/kg, internal energy: 13789 kJ/kg
# P= 2730 GPa. extrapolation not needed. density: 24203 kg/m^3, entropy: 836 J/K/kg, internal energy: 13792 kJ/kg
# P= 2740 GPa. extrapolation not needed. density: 24236 kg/m^3, entropy: 836 J/K/kg, internal energy: 13796 kJ/kg
# P= 2750 GPa. extrapolation not needed. density: 24269 kg/m^3, entropy: 837 J/K/kg, internal energy: 13800 kJ/kg
# P= 2760 GPa. extrapolation not needed. density: 24302 kg/m^3, entropy: 837 J/K/kg, internal energy: 13803 kJ/kg
# P= 2770 GPa. extrapolation not needed. density: 24334 kg/m^3, entropy: 837 J/K/kg, internal energy: 13807 kJ/kg
# P= 2780 GPa. extrapolation not needed. density: 24367 kg/m^3, entropy: 837 J/K/kg, internal energy: 13811 kJ/kg
# P= 2790 GPa. extrapolation not needed. density: 24400 kg/m^3, entropy: 838 J/K/kg, internal energy: 13814 kJ/kg
# P= 2800 GPa. extrapolation not needed. density: 24433 kg/m^3, entropy: 838 J/K/kg, internal energy: 13818 kJ/kg
# P= 2810 GPa. extrapolation not needed. density: 24465 kg/m^3, entropy: 838 J/K/kg, internal energy: 13821 kJ/kg
# P= 2820 GPa. extrapolation not needed. density: 24498 kg/m^3, entropy: 838 J/K/kg, internal energy: 13825 kJ/kg
# P= 2830 GPa. extrapolation not needed. density: 24530 kg/m^3, entropy: 839 J/K/kg, internal energy: 13828 kJ/kg
# P= 2840 GPa. extrapolation not needed. density: 24563 kg/m^3, entropy: 839 J/K/kg, internal energy: 13832 kJ/kg
# P= 2850 GPa. extrapolation not needed. density: 24595 kg/m^3, entropy: 839 J/K/kg, internal energy: 13835 kJ/kg
# P= 2860 GPa. extrapolation not needed. density: 24628 kg/m^3, entropy: 839 J/K/kg, internal energy: 13839 kJ/kg
# P= 2870 GPa. extrapolation not needed. density: 24660 kg/m^3, entropy: 840 J/K/kg, internal energy: 13842 kJ/kg
# P= 2880 GPa. extrapolation not needed. density: 24692 kg/m^3, entropy: 840 J/K/kg, internal energy: 13846 kJ/kg
# P= 2890 GPa. extrapolation not needed. density: 24724 kg/m^3, entropy: 840 J/K/kg, internal energy: 13849 kJ/kg
# P= 2900 GPa. extrapolation not needed. density: 24756 kg/m^3, entropy: 840 J/K/kg, internal energy: 13853 kJ/kg
# P= 2910 GPa. extrapolation not needed. density: 24788 kg/m^3, entropy: 841 J/K/kg, internal energy: 13856 kJ/kg
# P= 2920 GPa. extrapolation not needed. density: 24820 kg/m^3, entropy: 841 J/K/kg, internal energy: 13860 kJ/kg
# P= 2930 GPa. extrapolation not needed. density: 24852 kg/m^3, entropy: 841 J/K/kg, internal energy: 13863 kJ/kg
# P= 2940 GPa. extrapolation not needed. density: 24884 kg/m^3, entropy: 841 J/K/kg, internal energy: 13867 kJ/kg
# P= 2950 GPa. extrapolation not needed. density: 24916 kg/m^3, entropy: 842 J/K/kg, internal energy: 13870 kJ/kg
# P= 2960 GPa. extrapolation not needed. density: 24947 kg/m^3, entropy: 842 J/K/kg, internal energy: 13874 kJ/kg
# P= 2970 GPa. extrapolation not needed. density: 24979 kg/m^3, entropy: 842 J/K/kg, internal energy: 13877 kJ/kg
# P= 2980 GPa. extrapolation not needed. density: 25011 kg/m^3, entropy: 842 J/K/kg, internal energy: 13880 kJ/kg
# P= 2990 GPa. extrapolation not needed. density: 25042 kg/m^3, entropy: 843 J/K/kg, internal energy: 13884 kJ/kg
# P= 3000 GPa. extrapolation not needed. density: 25074 kg/m^3, entropy: 843 J/K/kg, internal energy: 13887 kJ/kg
# P= 3010 GPa. extrapolation not needed. density: 25105 kg/m^3, entropy: 843 J/K/kg, internal energy: 13891 kJ/kg
# P= 3020 GPa. extrapolation not needed. density: 25137 kg/m^3, entropy: 843 J/K/kg, internal energy: 13894 kJ/kg
# P= 3030 GPa. extrapolation not needed. density: 25168 kg/m^3, entropy: 843 J/K/kg, internal energy: 13897 kJ/kg
# P= 3040 GPa. extrapolation not needed. density: 25199 kg/m^3, entropy: 844 J/K/kg, internal energy: 13901 kJ/kg
# P= 3050 GPa. extrapolation not needed. density: 25230 kg/m^3, entropy: 844 J/K/kg, internal energy: 13904 kJ/kg
# P= 3060 GPa. extrapolation not needed. density: 25262 kg/m^3, entropy: 844 J/K/kg, internal energy: 13907 kJ/kg
# P= 3070 GPa. extrapolation not needed. density: 25293 kg/m^3, entropy: 844 J/K/kg, internal energy: 13911 kJ/kg
# P= 3080 GPa. extrapolation not needed. density: 25324 kg/m^3, entropy: 845 J/K/kg, internal energy: 13914 kJ/kg
# P= 3090 GPa. extrapolation not needed. density: 25355 kg/m^3, entropy: 845 J/K/kg, internal energy: 13917 kJ/kg
# P= 3100 GPa. extrapolation not needed. density: 25386 kg/m^3, entropy: 845 J/K/kg, internal energy: 13921 kJ/kg
# P= 3110 GPa. extrapolation not needed. density: 25416 kg/m^3, entropy: 845 J/K/kg, internal energy: 13924 kJ/kg
# P= 3120 GPa. extrapolation not needed. density: 25447 kg/m^3, entropy: 846 J/K/kg, internal energy: 13927 kJ/kg
# P= 3130 GPa. extrapolation not needed. density: 25478 kg/m^3, entropy: 846 J/K/kg, internal energy: 13930 kJ/kg
# P= 3140 GPa. extrapolation not needed. density: 25509 kg/m^3, entropy: 846 J/K/kg, internal energy: 13934 kJ/kg
# P= 3150 GPa. extrapolation not needed. density: 25539 kg/m^3, entropy: 846 J/K/kg, internal energy: 13937 kJ/kg
# P= 3160 GPa. extrapolation not needed. density: 25570 kg/m^3, entropy: 846 J/K/kg, internal energy: 13940 kJ/kg
# P= 3170 GPa. extrapolation not needed. density: 25601 kg/m^3, entropy: 847 J/K/kg, internal energy: 13943 kJ/kg
# P= 3180 GPa. extrapolation not needed. density: 25631 kg/m^3, entropy: 847 J/K/kg, internal energy: 13947 kJ/kg
# P= 3190 GPa. extrapolation not needed. density: 25662 kg/m^3, entropy: 847 J/K/kg, internal energy: 13950 kJ/kg
# P= 3200 GPa. extrapolation not needed. density: 25692 kg/m^3, entropy: 847 J/K/kg, internal energy: 13953 kJ/kg
# P= 3210 GPa. extrapolation not needed. density: 25722 kg/m^3, entropy: 848 J/K/kg, internal energy: 13956 kJ/kg
# P= 3220 GPa. extrapolation not needed. density: 25753 kg/m^3, entropy: 848 J/K/kg, internal energy: 13960 kJ/kg
# P= 3230 GPa. extrapolation not needed. density: 25783 kg/m^3, entropy: 848 J/K/kg, internal energy: 13963 kJ/kg
# P= 3240 GPa. extrapolation not needed. density: 25813 kg/m^3, entropy: 848 J/K/kg, internal energy: 13966 kJ/kg
# P= 3250 GPa. extrapolation not needed. density: 25843 kg/m^3, entropy: 849 J/K/kg, internal energy: 13969 kJ/kg
# P= 3260 GPa. extrapolation not needed. density: 25873 kg/m^3, entropy: 849 J/K/kg, internal energy: 13972 kJ/kg
# P= 3270 GPa. extrapolation not needed. density: 25903 kg/m^3, entropy: 849 J/K/kg, internal energy: 13976 kJ/kg
# P= 3280 GPa. extrapolation not needed. density: 25933 kg/m^3, entropy: 849 J/K/kg, internal energy: 13979 kJ/kg
# P= 3290 GPa. extrapolation not needed. density: 25963 kg/m^3, entropy: 849 J/K/kg, internal energy: 13982 kJ/kg
# P= 3300 GPa. extrapolation not needed. density: 25993 kg/m^3, entropy: 850 J/K/kg, internal energy: 13985 kJ/kg
# P= 3310 GPa. extrapolation not needed. density: 26023 kg/m^3, entropy: 850 J/K/kg, internal energy: 13988 kJ/kg
# P= 3320 GPa. extrapolation not needed. density: 26053 kg/m^3, entropy: 850 J/K/kg, internal energy: 13991 kJ/kg
# P= 3330 GPa. extrapolation not needed. density: 26083 kg/m^3, entropy: 850 J/K/kg, internal energy: 13994 kJ/kg
# P= 3340 GPa. extrapolation not needed. density: 26113 kg/m^3, entropy: 850 J/K/kg, internal energy: 13998 kJ/kg
# P= 3350 GPa. extrapolation not needed. density: 26142 kg/m^3, entropy: 851 J/K/kg, internal energy: 14001 kJ/kg
# P= 3360 GPa. extrapolation not needed. density: 26172 kg/m^3, entropy: 851 J/K/kg, internal energy: 14004 kJ/kg
# P= 3370 GPa. extrapolation not needed. density: 26201 kg/m^3, entropy: 851 J/K/kg, internal energy: 14007 kJ/kg
# P= 3380 GPa. extrapolation not needed. density: 26231 kg/m^3, entropy: 851 J/K/kg, internal energy: 14010 kJ/kg
# P= 3390 GPa. extrapolation not needed. density: 26260 kg/m^3, entropy: 852 J/K/kg, internal energy: 14013 kJ/kg
# P= 3400 GPa. extrapolation not needed. density: 26290 kg/m^3, entropy: 852 J/K/kg, internal energy: 14016 kJ/kg
# P= 3410 GPa. extrapolation not needed. density: 26319 kg/m^3, entropy: 852 J/K/kg, internal energy: 14019 kJ/kg
# P= 3420 GPa. extrapolation not needed. density: 26349 kg/m^3, entropy: 852 J/K/kg, internal energy: 14022 kJ/kg
# P= 3430 GPa. extrapolation not needed. density: 26378 kg/m^3, entropy: 852 J/K/kg, internal energy: 14025 kJ/kg
# P= 3440 GPa. extrapolation not needed. density: 26407 kg/m^3, entropy: 853 J/K/kg, internal energy: 14028 kJ/kg
# P= 3450 GPa. extrapolation not needed. density: 26436 kg/m^3, entropy: 853 J/K/kg, internal energy: 14031 kJ/kg
# P= 3460 GPa. extrapolation not needed. density: 26465 kg/m^3, entropy: 853 J/K/kg, internal energy: 14034 kJ/kg
# P= 3470 GPa. extrapolation not needed. density: 26495 kg/m^3, entropy: 853 J/K/kg, internal energy: 14037 kJ/kg
# P= 3480 GPa. extrapolation not needed. density: 26524 kg/m^3, entropy: 854 J/K/kg, internal energy: 14040 kJ/kg
# P= 3490 GPa. extrapolation not needed. density: 26553 kg/m^3, entropy: 854 J/K/kg, internal energy: 14044 kJ/kg
# P= 3500 GPa. extrapolation not needed. density: 26582 kg/m^3, entropy: 854 J/K/kg, internal energy: 14047 kJ/kg
# P= 3510 GPa. extrapolation not needed. density: 26611 kg/m^3, entropy: 854 J/K/kg, internal energy: 14050 kJ/kg
# P= 3520 GPa. extrapolation not needed. density: 26640 kg/m^3, entropy: 854 J/K/kg, internal energy: 14053 kJ/kg
# P= 3530 GPa. extrapolation not needed. density: 26668 kg/m^3, entropy: 855 J/K/kg, internal energy: 14056 kJ/kg
# P= 3540 GPa. extrapolation not needed. density: 26697 kg/m^3, entropy: 855 J/K/kg, internal energy: 14058 kJ/kg
# P= 3550 GPa. extrapolation not needed. density: 26726 kg/m^3, entropy: 855 J/K/kg, internal energy: 14061 kJ/kg
# P= 3560 GPa. extrapolation not needed. density: 26755 kg/m^3, entropy: 855 J/K/kg, internal energy: 14064 kJ/kg
# P= 3570 GPa. extrapolation not needed. density: 26783 kg/m^3, entropy: 855 J/K/kg, internal energy: 14067 kJ/kg
# P= 3580 GPa. extrapolation not needed. density: 26812 kg/m^3, entropy: 856 J/K/kg, internal energy: 14070 kJ/kg
# P= 3590 GPa. extrapolation not needed. density: 26841 kg/m^3, entropy: 856 J/K/kg, internal energy: 14073 kJ/kg
# P= 3600 GPa. extrapolation not needed. density: 26869 kg/m^3, entropy: 856 J/K/kg, internal energy: 14076 kJ/kg
# P= 3610 GPa. extrapolation not needed. density: 26898 kg/m^3, entropy: 856 J/K/kg, internal energy: 14079 kJ/kg
# P= 3620 GPa. extrapolation not needed. density: 26926 kg/m^3, entropy: 856 J/K/kg, internal energy: 14082 kJ/kg
# P= 3630 GPa. extrapolation not needed. density: 26954 kg/m^3, entropy: 857 J/K/kg, internal energy: 14085 kJ/kg
# P= 3640 GPa. extrapolation not needed. density: 26983 kg/m^3, entropy: 857 J/K/kg, internal energy: 14088 kJ/kg
# P= 3650 GPa. extrapolation not needed. density: 27011 kg/m^3, entropy: 857 J/K/kg, internal energy: 14091 kJ/kg
# P= 3660 GPa. extrapolation not needed. density: 27040 kg/m^3, entropy: 857 J/K/kg, internal energy: 14094 kJ/kg
# P= 3670 GPa. extrapolation not needed. density: 27068 kg/m^3, entropy: 857 J/K/kg, internal energy: 14097 kJ/kg
# P= 3680 GPa. extrapolation not needed. density: 27096 kg/m^3, entropy: 858 J/K/kg, internal energy: 14100 kJ/kg
# P= 3690 GPa. extrapolation not needed. density: 27124 kg/m^3, entropy: 858 J/K/kg, internal energy: 14103 kJ/kg
# P= 3700 GPa. extrapolation not needed. density: 27152 kg/m^3, entropy: 858 J/K/kg, internal energy: 14105 kJ/kg
# P= 3710 GPa. extrapolation not needed. density: 27180 kg/m^3, entropy: 858 J/K/kg, internal energy: 14108 kJ/kg
# P= 3720 GPa. extrapolation not needed. density: 27208 kg/m^3, entropy: 858 J/K/kg, internal energy: 14111 kJ/kg
# P= 3730 GPa. extrapolation not needed. density: 27236 kg/m^3, entropy: 859 J/K/kg, internal energy: 14114 kJ/kg
# P= 3740 GPa. extrapolation not needed. density: 27264 kg/m^3, entropy: 859 J/K/kg, internal energy: 14117 kJ/kg
# P= 3750 GPa. extrapolation not needed. density: 27292 kg/m^3, entropy: 859 J/K/kg, internal energy: 14120 kJ/kg
# P= 3760 GPa. extrapolation not needed. density: 27320 kg/m^3, entropy: 859 J/K/kg, internal energy: 14123 kJ/kg
# P= 3770 GPa. extrapolation not needed. density: 27348 kg/m^3, entropy: 859 J/K/kg, internal energy: 14125 kJ/kg
# P= 3780 GPa. extrapolation not needed. density: 27376 kg/m^3, entropy: 860 J/K/kg, internal energy: 14128 kJ/kg
# P= 3790 GPa. extrapolation not needed. density: 27404 kg/m^3, entropy: 860 J/K/kg, internal energy: 14131 kJ/kg
# P= 3800 GPa. extrapolation not needed. density: 27432 kg/m^3, entropy: 860 J/K/kg, internal energy: 14134 kJ/kg
# P= 3810 GPa. extrapolation not needed. density: 27459 kg/m^3, entropy: 860 J/K/kg, internal energy: 14137 kJ/kg
# P= 3820 GPa. extrapolation not needed. density: 27487 kg/m^3, entropy: 860 J/K/kg, internal energy: 14140 kJ/kg
# P= 3830 GPa. extrapolation not needed. density: 27515 kg/m^3, entropy: 861 J/K/kg, internal energy: 14142 kJ/kg
# P= 3840 GPa. extrapolation not needed. density: 27542 kg/m^3, entropy: 861 J/K/kg, internal energy: 14145 kJ/kg
# P= 3850 GPa. extrapolation not needed. density: 27570 kg/m^3, entropy: 861 J/K/kg, internal energy: 14148 kJ/kg
# P= 3860 GPa. extrapolation not needed. density: 27597 kg/m^3, entropy: 861 J/K/kg, internal energy: 14151 kJ/kg
# P= 3870 GPa. extrapolation not needed. density: 27625 kg/m^3, entropy: 861 J/K/kg, internal energy: 14154 kJ/kg
# P= 3880 GPa. extrapolation not needed. density: 27652 kg/m^3, entropy: 862 J/K/kg, internal energy: 14156 kJ/kg
# P= 3890 GPa. extrapolation not needed. density: 27679 kg/m^3, entropy: 862 J/K/kg, internal energy: 14159 kJ/kg
# P= 3900 GPa. extrapolation not needed. density: 27707 kg/m^3, entropy: 862 J/K/kg, internal energy: 14162 kJ/kg
# P= 3910 GPa. extrapolation not needed. density: 27734 kg/m^3, entropy: 862 J/K/kg, internal energy: 14165 kJ/kg
# P= 3920 GPa. extrapolation not needed. density: 27761 kg/m^3, entropy: 862 J/K/kg, internal energy: 14167 kJ/kg
# P= 3930 GPa. extrapolation not needed. density: 27789 kg/m^3, entropy: 863 J/K/kg, internal energy: 14170 kJ/kg
# P= 3940 GPa. extrapolation not needed. density: 27816 kg/m^3, entropy: 863 J/K/kg, internal energy: 14173 kJ/kg
# P= 3950 GPa. extrapolation not needed. density: 27843 kg/m^3, entropy: 863 J/K/kg, internal energy: 14176 kJ/kg
# P= 3960 GPa. extrapolation not needed. density: 27870 kg/m^3, entropy: 863 J/K/kg, internal energy: 14178 kJ/kg
# P= 3970 GPa. extrapolation not needed. density: 27897 kg/m^3, entropy: 863 J/K/kg, internal energy: 14181 kJ/kg
# P= 3980 GPa. extrapolation not needed. density: 27924 kg/m^3, entropy: 864 J/K/kg, internal energy: 14184 kJ/kg
# P= 3990 GPa. extrapolation not needed. density: 27951 kg/m^3, entropy: 864 J/K/kg, internal energy: 14187 kJ/kg
# P= 4000 GPa. extrapolation not needed. density: 27978 kg/m^3, entropy: 864 J/K/kg, internal energy: 14189 kJ/kg
# P= 4010 GPa. extrapolation not needed. density: 28005 kg/m^3, entropy: 864 J/K/kg, internal energy: 14192 kJ/kg
# P= 4020 GPa. extrapolation not needed. density: 28032 kg/m^3, entropy: 864 J/K/kg, internal energy: 14195 kJ/kg
# P= 4030 GPa. extrapolation not needed. density: 28059 kg/m^3, entropy: 865 J/K/kg, internal energy: 14197 kJ/kg
# P= 4040 GPa. extrapolation not needed. density: 28086 kg/m^3, entropy: 865 J/K/kg, internal energy: 14200 kJ/kg
# P= 4050 GPa. extrapolation not needed. density: 28113 kg/m^3, entropy: 865 J/K/kg, internal energy: 14203 kJ/kg
# P= 4060 GPa. extrapolation not needed. density: 28140 kg/m^3, entropy: 865 J/K/kg, internal energy: 14206 kJ/kg
# P= 4070 GPa. extrapolation not needed. density: 28167 kg/m^3, entropy: 865 J/K/kg, internal energy: 14208 kJ/kg
# P= 4080 GPa. extrapolation not needed. density: 28193 kg/m^3, entropy: 866 J/K/kg, internal energy: 14211 kJ/kg
# P= 4090 GPa. extrapolation not needed. density: 28220 kg/m^3, entropy: 866 J/K/kg, internal energy: 14214 kJ/kg
# P= 4100 GPa. extrapolation not needed. density: 28247 kg/m^3, entropy: 866 J/K/kg, internal energy: 14216 kJ/kg
# P= 4110 GPa. extrapolation not needed. density: 28273 kg/m^3, entropy: 866 J/K/kg, internal energy: 14219 kJ/kg
# P= 4120 GPa. extrapolation not needed. density: 28300 kg/m^3, entropy: 866 J/K/kg, internal energy: 14222 kJ/kg
# P= 4130 GPa. extrapolation not needed. density: 28326 kg/m^3, entropy: 866 J/K/kg, internal energy: 14224 kJ/kg
# P= 4140 GPa. extrapolation not needed. density: 28353 kg/m^3, entropy: 867 J/K/kg, internal energy: 14227 kJ/kg
# P= 4150 GPa. extrapolation not needed. density: 28379 kg/m^3, entropy: 867 J/K/kg, internal energy: 14230 kJ/kg
# P= 4160 GPa. extrapolation not needed. density: 28406 kg/m^3, entropy: 867 J/K/kg, internal energy: 14232 kJ/kg
# P= 4170 GPa. extrapolation not needed. density: 28432 kg/m^3, entropy: 867 J/K/kg, internal energy: 14235 kJ/kg
# P= 4180 GPa. extrapolation not needed. density: 28459 kg/m^3, entropy: 867 J/K/kg, internal energy: 14237 kJ/kg
# P= 4190 GPa. extrapolation not needed. density: 28485 kg/m^3, entropy: 868 J/K/kg, internal energy: 14240 kJ/kg
# P= 4200 GPa. extrapolation not needed. density: 28511 kg/m^3, entropy: 868 J/K/kg, internal energy: 14243 kJ/kg
# P= 4210 GPa. extrapolation not needed. density: 28538 kg/m^3, entropy: 868 J/K/kg, internal energy: 14245 kJ/kg
# P= 4220 GPa. extrapolation not needed. density: 28564 kg/m^3, entropy: 868 J/K/kg, internal energy: 14248 kJ/kg
# P= 4230 GPa. extrapolation not needed. density: 28590 kg/m^3, entropy: 868 J/K/kg, internal energy: 14251 kJ/kg
# P= 4240 GPa. extrapolation not needed. density: 28616 kg/m^3, entropy: 868 J/K/kg, internal energy: 14253 kJ/kg
# P= 4250 GPa. extrapolation not needed. density: 28642 kg/m^3, entropy: 869 J/K/kg, internal energy: 14256 kJ/kg
# P= 4260 GPa. extrapolation not needed. density: 28669 kg/m^3, entropy: 869 J/K/kg, internal energy: 14258 kJ/kg
# P= 4270 GPa. extrapolation not needed. density: 28695 kg/m^3, entropy: 869 J/K/kg, internal energy: 14261 kJ/kg
# P= 4280 GPa. extrapolation not needed. density: 28721 kg/m^3, entropy: 869 J/K/kg, internal energy: 14263 kJ/kg
# ...
# P= 8590 GPa. extrapolation not needed. density: 37983 kg/m^3, entropy: 928 J/K/kg, internal energy: 15106 kJ/kg
# P= 8600 GPa. extrapolation not needed. density: 38002 kg/m^3, entropy: 929 J/K/kg, internal energy: 15107 kJ/kg
# P= 8610 GPa. extrapolation not needed. density: 38020 kg/m^3, entropy: 929 J/K/kg, internal energy: 15109 kJ/kg
# P= 8620 GPa. extrapolation not needed. density: 38038 kg/m^3, entropy: 929 J/K/kg, internal energy: 15110 kJ/kg
# P= 8630 GPa. extrapolation not needed. density: 38057 kg/m^3, entropy: 929 J/K/kg, internal energy: 15112 kJ/kg
# P= 8640 GPa. extrapolation not needed. density: 38075 kg/m^3, entropy: 929 J/K/kg, internal energy: 15113 kJ/kg
# P= 8650 GPa. extrapolation not needed. density: 38093 kg/m^3, entropy: 929 J/K/kg, internal energy: 15115 kJ/kg
# P= 8660 GPa. extrapolation not needed. density: 38112 kg/m^3, entropy: 929 J/K/kg, internal energy: 15116 kJ/kg
# P= 8670 GPa. extrapolation not needed. density: 38130 kg/m^3, entropy: 929 J/K/kg, internal energy: 15118 kJ/kg
# P= 8680 GPa. extrapolation not needed. density: 38148 kg/m^3, entropy: 929 J/K/kg, internal energy: 15119 kJ/kg
# P= 8690 GPa. extrapolation not needed. density: 38166 kg/m^3, entropy: 929 J/K/kg, internal energy: 15121 kJ/kg
# P= 8700 GPa. extrapolation not needed. density: 38185 kg/m^3, entropy: 930 J/K/kg, internal energy: 15122 kJ/kg
# P= 8710 GPa. extrapolation not needed. density: 38203 kg/m^3, entropy: 930 J/K/kg, internal energy: 15124 kJ/kg
# P= 8720 GPa. extrapolation not needed. density: 38221 kg/m^3, entropy: 930 J/K/kg, internal energy: 15125 kJ/kg
# P= 8730 GPa. extrapolation not needed. density: 38239 kg/m^3, entropy: 930 J/K/kg, internal energy: 15127 kJ/kg
# P= 8740 GPa. extrapolation not needed. density: 38258 kg/m^3, entropy: 930 J/K/kg, internal energy: 15129 kJ/kg
# P= 8750 GPa. extrapolation not needed. density: 38276 kg/m^3, entropy: 930 J/K/kg, internal energy: 15130 kJ/kg
# P= 8760 GPa. extrapolation not needed. density: 38294 kg/m^3, entropy: 930 J/K/kg, internal energy: 15132 kJ/kg
# P= 8770 GPa. extrapolation not needed. density: 38312 kg/m^3, entropy: 930 J/K/kg, internal energy: 15133 kJ/kg
# P= 8780 GPa. extrapolation not needed. density: 38330 kg/m^3, entropy: 930 J/K/kg, internal energy: 15135 kJ/kg
# P= 8790 GPa. extrapolation not needed. density: 38349 kg/m^3, entropy: 931 J/K/kg, internal energy: 15136 kJ/kg
# P= 8800 GPa. extrapolation not needed. density: 38367 kg/m^3, entropy: 931 J/K/kg, internal energy: 15138 kJ/kg
# P= 8810 GPa. extrapolation not needed. density: 38385 kg/m^3, entropy: 931 J/K/kg, internal energy: 15139 kJ/kg
# P= 8820 GPa. extrapolation not needed. density: 38403 kg/m^3, entropy: 931 J/K/kg, internal energy: 15141 kJ/kg
# P= 8830 GPa. extrapolation not needed. density: 38421 kg/m^3, entropy: 931 J/K/kg, internal energy: 15142 kJ/kg
# P= 8840 GPa. extrapolation not needed. density: 38439 kg/m^3, entropy: 931 J/K/kg, internal energy: 15144 kJ/kg
# P= 8850 GPa. extrapolation not needed. density: 38457 kg/m^3, entropy: 931 J/K/kg, internal energy: 15145 kJ/kg
# P= 8860 GPa. extrapolation not needed. density: 38475 kg/m^3, entropy: 931 J/K/kg, internal energy: 15147 kJ/kg
# P= 8870 GPa. extrapolation not needed. density: 38494 kg/m^3, entropy: 931 J/K/kg, internal energy: 15148 kJ/kg
# P= 8880 GPa. extrapolation not needed. density: 38512 kg/m^3, entropy: 932 J/K/kg, internal energy: 15150 kJ/kg
# P= 8890 GPa. extrapolation not needed. density: 38530 kg/m^3, entropy: 932 J/K/kg, internal energy: 15151 kJ/kg
# P= 8900 GPa. extrapolation not needed. density: 38548 kg/m^3, entropy: 932 J/K/kg, internal energy: 15153 kJ/kg
# P= 8910 GPa. extrapolation not needed. density: 38566 kg/m^3, entropy: 932 J/K/kg, internal energy: 15154 kJ/kg
# P= 8920 GPa. extrapolation not needed. density: 38584 kg/m^3, entropy: 932 J/K/kg, internal energy: 15156 kJ/kg
# P= 8930 GPa. extrapolation not needed. density: 38602 kg/m^3, entropy: 932 J/K/kg, internal energy: 15157 kJ/kg
# P= 8940 GPa. extrapolation not needed. density: 38620 kg/m^3, entropy: 932 J/K/kg, internal energy: 15159 kJ/kg
# P= 8950 GPa. extrapolation not needed. density: 38638 kg/m^3, entropy: 932 J/K/kg, internal energy: 15160 kJ/kg
# P= 8960 GPa. extrapolation not needed. density: 38656 kg/m^3, entropy: 932 J/K/kg, internal energy: 15162 kJ/kg
# P= 8970 GPa. extrapolation not needed. density: 38674 kg/m^3, entropy: 932 J/K/kg, internal energy: 15163 kJ/kg
# P= 8980 GPa. extrapolation not needed. density: 38692 kg/m^3, entropy: 933 J/K/kg, internal energy: 15165 kJ/kg
# P= 8990 GPa. extrapolation not needed. density: 38710 kg/m^3, entropy: 933 J/K/kg, internal energy: 15166 kJ/kg
# P= 9000 GPa. extrapolation not needed. density: 38728 kg/m^3, entropy: 933 J/K/kg, internal energy: 15168 kJ/kg
# P= 9010 GPa. extrapolation not needed. density: 38746 kg/m^3, entropy: 933 J/K/kg, internal energy: 15169 kJ/kg
# P= 9020 GPa. extrapolation not needed. density: 38764 kg/m^3, entropy: 933 J/K/kg, internal energy: 15171 kJ/kg
# P= 9030 GPa. extrapolation not needed. density: 38782 kg/m^3, entropy: 933 J/K/kg, internal energy: 15172 kJ/kg
# P= 9040 GPa. extrapolation not needed. density: 38799 kg/m^3, entropy: 933 J/K/kg, internal energy: 15174 kJ/kg
# P= 9050 GPa. extrapolation not needed. density: 38817 kg/m^3, entropy: 933 J/K/kg, internal energy: 15175 kJ/kg
# P= 9060 GPa. extrapolation not needed. density: 38835 kg/m^3, entropy: 933 J/K/kg, internal energy: 15176 kJ/kg
# P= 9070 GPa. extrapolation not needed. density: 38853 kg/m^3, entropy: 933 J/K/kg, internal energy: 15178 kJ/kg
# P= 9080 GPa. extrapolation not needed. density: 38871 kg/m^3, entropy: 934 J/K/kg, internal energy: 15179 kJ/kg
# P= 9090 GPa. extrapolation not needed. density: 38889 kg/m^3, entropy: 934 J/K/kg, internal energy: 15181 kJ/kg
# P= 9100 GPa. extrapolation not needed. density: 38907 kg/m^3, entropy: 934 J/K/kg, internal energy: 15182 kJ/kg
# P= 9110 GPa. extrapolation not needed. density: 38925 kg/m^3, entropy: 934 J/K/kg, internal energy: 15184 kJ/kg
# P= 9120 GPa. extrapolation not needed. density: 38942 kg/m^3, entropy: 934 J/K/kg, internal energy: 15185 kJ/kg
# P= 9130 GPa. extrapolation not needed. density: 38960 kg/m^3, entropy: 934 J/K/kg, internal energy: 15187 kJ/kg
# P= 9140 GPa. extrapolation not needed. density: 38978 kg/m^3, entropy: 934 J/K/kg, internal energy: 15188 kJ/kg
# P= 9150 GPa. extrapolation not needed. density: 38996 kg/m^3, entropy: 934 J/K/kg, internal energy: 15190 kJ/kg
# P= 9160 GPa. extrapolation not needed. density: 39014 kg/m^3, entropy: 934 J/K/kg, internal energy: 15191 kJ/kg
# P= 9170 GPa. extrapolation not needed. density: 39032 kg/m^3, entropy: 935 J/K/kg, internal energy: 15193 kJ/kg
# P= 9180 GPa. extrapolation not needed. density: 39049 kg/m^3, entropy: 935 J/K/kg, internal energy: 15194 kJ/kg
# P= 9190 GPa. extrapolation not needed. density: 39067 kg/m^3, entropy: 935 J/K/kg, internal energy: 15196 kJ/kg
# P= 9200 GPa. extrapolation not needed. density: 39085 kg/m^3, entropy: 935 J/K/kg, internal energy: 15197 kJ/kg
# P= 9210 GPa. extrapolation not needed. density: 39103 kg/m^3, entropy: 935 J/K/kg, internal energy: 15199 kJ/kg
# P= 9220 GPa. extrapolation not needed. density: 39120 kg/m^3, entropy: 935 J/K/kg, internal energy: 15200 kJ/kg
# P= 9230 GPa. extrapolation not needed. density: 39138 kg/m^3, entropy: 935 J/K/kg, internal energy: 15201 kJ/kg
# P= 9240 GPa. extrapolation not needed. density: 39156 kg/m^3, entropy: 935 J/K/kg, internal energy: 15203 kJ/kg
# P= 9250 GPa. extrapolation not needed. density: 39174 kg/m^3, entropy: 935 J/K/kg, internal energy: 15204 kJ/kg
# P= 9260 GPa. extrapolation not needed. density: 39191 kg/m^3, entropy: 935 J/K/kg, internal energy: 15206 kJ/kg
# P= 9270 GPa. extrapolation not needed. density: 39209 kg/m^3, entropy: 936 J/K/kg, internal energy: 15207 kJ/kg
# P= 9280 GPa. extrapolation not needed. density: 39227 kg/m^3, entropy: 936 J/K/kg, internal energy: 15209 kJ/kg
# P= 9290 GPa. extrapolation not needed. density: 39244 kg/m^3, entropy: 936 J/K/kg, internal energy: 15210 kJ/kg
# P= 9300 GPa. extrapolation not needed. density: 39262 kg/m^3, entropy: 936 J/K/kg, internal energy: 15212 kJ/kg
# P= 9310 GPa. extrapolation not needed. density: 39280 kg/m^3, entropy: 936 J/K/kg, internal energy: 15213 kJ/kg
# P= 9320 GPa. extrapolation not needed. density: 39297 kg/m^3, entropy: 936 J/K/kg, internal energy: 15215 kJ/kg
# P= 9330 GPa. extrapolation not needed. density: 39315 kg/m^3, entropy: 936 J/K/kg, internal energy: 15216 kJ/kg
# P= 9340 GPa. extrapolation not needed. density: 39333 kg/m^3, entropy: 936 J/K/kg, internal energy: 15217 kJ/kg
# P= 9350 GPa. extrapolation not needed. density: 39350 kg/m^3, entropy: 936 J/K/kg, internal energy: 15219 kJ/kg
# P= 9360 GPa. extrapolation not needed. density: 39368 kg/m^3, entropy: 936 J/K/kg, internal energy: 15220 kJ/kg
# P= 9370 GPa. extrapolation not needed. density: 39386 kg/m^3, entropy: 937 J/K/kg, internal energy: 15222 kJ/kg
# P= 9380 GPa. extrapolation not needed. density: 39403 kg/m^3, entropy: 937 J/K/kg, internal energy: 15223 kJ/kg
# P= 9390 GPa. extrapolation not needed. density: 39421 kg/m^3, entropy: 937 J/K/kg, internal energy: 15225 kJ/kg
# P= 9400 GPa. extrapolation not needed. density: 39438 kg/m^3, entropy: 937 J/K/kg, internal energy: 15226 kJ/kg
# P= 9410 GPa. extrapolation not needed. density: 39456 kg/m^3, entropy: 937 J/K/kg, internal energy: 15228 kJ/kg
# P= 9420 GPa. extrapolation not needed. density: 39474 kg/m^3, entropy: 937 J/K/kg, internal energy: 15229 kJ/kg
# P= 9430 GPa. extrapolation not needed. density: 39491 kg/m^3, entropy: 937 J/K/kg, internal energy: 15230 kJ/kg
# P= 9440 GPa. extrapolation not needed. density: 39509 kg/m^3, entropy: 937 J/K/kg, internal energy: 15232 kJ/kg
# P= 9450 GPa. extrapolation not needed. density: 39526 kg/m^3, entropy: 937 J/K/kg, internal energy: 15233 kJ/kg
# P= 9460 GPa. extrapolation not needed. density: 39544 kg/m^3, entropy: 937 J/K/kg, internal energy: 15235 kJ/kg
# P= 9470 GPa. extrapolation not needed. density: 39561 kg/m^3, entropy: 938 J/K/kg, internal energy: 15236 kJ/kg
# P= 9480 GPa. extrapolation not needed. density: 39579 kg/m^3, entropy: 938 J/K/kg, internal energy: 15238 kJ/kg
# P= 9490 GPa. extrapolation not needed. density: 39596 kg/m^3, entropy: 938 J/K/kg, internal energy: 15239 kJ/kg
# P= 9500 GPa. extrapolation not needed. density: 39614 kg/m^3, entropy: 938 J/K/kg, internal energy: 15241 kJ/kg
# P= 9510 GPa. extrapolation not needed. density: 39631 kg/m^3, entropy: 938 J/K/kg, internal energy: 15242 kJ/kg
# P= 9520 GPa. extrapolation not needed. density: 39649 kg/m^3, entropy: 938 J/K/kg, internal energy: 15243 kJ/kg
# P= 9530 GPa. extrapolation not needed. density: 39666 kg/m^3, entropy: 938 J/K/kg, internal energy: 15245 kJ/kg
# P= 9540 GPa. extrapolation not needed. density: 39684 kg/m^3, entropy: 938 J/K/kg, internal energy: 15246 kJ/kg
# P= 9550 GPa. extrapolation not needed. density: 39701 kg/m^3, entropy: 938 J/K/kg, internal energy: 15248 kJ/kg
# P= 9560 GPa. extrapolation not needed. density: 39719 kg/m^3, entropy: 938 J/K/kg, internal energy: 15249 kJ/kg
# P= 9570 GPa. extrapolation not needed. density: 39736 kg/m^3, entropy: 939 J/K/kg, internal energy: 15250 kJ/kg
# P= 9580 GPa. extrapolation not needed. density: 39753 kg/m^3, entropy: 939 J/K/kg, internal energy: 15252 kJ/kg
# P= 9590 GPa. extrapolation not needed. density: 39771 kg/m^3, entropy: 939 J/K/kg, internal energy: 15253 kJ/kg
# P= 9600 GPa. extrapolation not needed. density: 39788 kg/m^3, entropy: 939 J/K/kg, internal energy: 15255 kJ/kg
# P= 9610 GPa. extrapolation not needed. density: 39806 kg/m^3, entropy: 939 J/K/kg, internal energy: 15256 kJ/kg
# P= 9620 GPa. extrapolation not needed. density: 39823 kg/m^3, entropy: 939 J/K/kg, internal energy: 15258 kJ/kg
# P= 9630 GPa. extrapolation not needed. density: 39840 kg/m^3, entropy: 939 J/K/kg, internal energy: 15259 kJ/kg
# P= 9640 GPa. extrapolation not needed. density: 39858 kg/m^3, entropy: 939 J/K/kg, internal energy: 15260 kJ/kg
# P= 9650 GPa. extrapolation not needed. density: 39875 kg/m^3, entropy: 939 J/K/kg, internal energy: 15262 kJ/kg
# P= 9660 GPa. extrapolation not needed. density: 39893 kg/m^3, entropy: 939 J/K/kg, internal energy: 15263 kJ/kg
# P= 9670 GPa. extrapolation not needed. density: 39910 kg/m^3, entropy: 940 J/K/kg, internal energy: 15265 kJ/kg
# P= 9680 GPa. extrapolation not needed. density: 39927 kg/m^3, entropy: 940 J/K/kg, internal energy: 15266 kJ/kg
# P= 9690 GPa. extrapolation not needed. density: 39945 kg/m^3, entropy: 940 J/K/kg, internal energy: 15267 kJ/kg
# P= 9700 GPa. extrapolation not needed. density: 39962 kg/m^3, entropy: 940 J/K/kg, internal energy: 15269 kJ/kg
# P= 9710 GPa. extrapolation not needed. density: 39979 kg/m^3, entropy: 940 J/K/kg, internal energy: 15270 kJ/kg
# P= 9720 GPa. extrapolation not needed. density: 39997 kg/m^3, entropy: 940 J/K/kg, internal energy: 15272 kJ/kg
# P= 9730 GPa. extrapolation not needed. density: 40014 kg/m^3, entropy: 940 J/K/kg, internal energy: 15273 kJ/kg
# P= 9740 GPa. extrapolation not needed. density: 40031 kg/m^3, entropy: 940 J/K/kg, internal energy: 15275 kJ/kg
# P= 9750 GPa. extrapolation not needed. density: 40048 kg/m^3, entropy: 940 J/K/kg, internal energy: 15276 kJ/kg
# P= 9760 GPa. extrapolation not needed. density: 40066 kg/m^3, entropy: 940 J/K/kg, internal energy: 15277 kJ/kg
# P= 9770 GPa. extrapolation not needed. density: 40083 kg/m^3, entropy: 941 J/K/kg, internal energy: 15279 kJ/kg
# P= 9780 GPa. extrapolation not needed. density: 40100 kg/m^3, entropy: 941 J/K/kg, internal energy: 15280 kJ/kg
# P= 9790 GPa. extrapolation not needed. density: 40118 kg/m^3, entropy: 941 J/K/kg, internal energy: 15282 kJ/kg
# P= 9800 GPa. extrapolation not needed. density: 40135 kg/m^3, entropy: 941 J/K/kg, internal energy: 15283 kJ/kg
# P= 9810 GPa. extrapolation not needed. density: 40152 kg/m^3, entropy: 941 J/K/kg, internal energy: 15284 kJ/kg
# P= 9820 GPa. extrapolation not needed. density: 40169 kg/m^3, entropy: 941 J/K/kg, internal energy: 15286 kJ/kg
# P= 9830 GPa. extrapolation not needed. density: 40186 kg/m^3, entropy: 941 J/K/kg, internal energy: 15287 kJ/kg
# P= 9840 GPa. extrapolation not needed. density: 40204 kg/m^3, entropy: 941 J/K/kg, internal energy: 15289 kJ/kg
# P= 9850 GPa. extrapolation not needed. density: 40221 kg/m^3, entropy: 941 J/K/kg, internal energy: 15290 kJ/kg
# P= 9860 GPa. extrapolation not needed. density: 40238 kg/m^3, entropy: 941 J/K/kg, internal energy: 15291 kJ/kg
# P= 9870 GPa. extrapolation not needed. density: 40255 kg/m^3, entropy: 942 J/K/kg, internal energy: 15293 kJ/kg
# P= 9880 GPa. extrapolation not needed. density: 40272 kg/m^3, entropy: 942 J/K/kg, internal energy: 15294 kJ/kg
# P= 9890 GPa. extrapolation not needed. density: 40290 kg/m^3, entropy: 942 J/K/kg, internal energy: 15295 kJ/kg
# P= 9900 GPa. extrapolation not needed. density: 40307 kg/m^3, entropy: 942 J/K/kg, internal energy: 15297 kJ/kg
# P= 9910 GPa. extrapolation not needed. density: 40324 kg/m^3, entropy: 942 J/K/kg, internal energy: 15298 kJ/kg
# P= 9920 GPa. extrapolation not needed. density: 40341 kg/m^3, entropy: 942 J/K/kg, internal energy: 15300 kJ/kg
# P= 9930 GPa. extrapolation not needed. density: 40358 kg/m^3, entropy: 942 J/K/kg, internal energy: 15301 kJ/kg
# P= 9940 GPa. extrapolation not needed. density: 40375 kg/m^3, entropy: 942 J/K/kg, internal energy: 15302 kJ/kg
# P= 9950 GPa. extrapolation not needed. density: 40392 kg/m^3, entropy: 942 J/K/kg, internal energy: 15304 kJ/kg
# P= 9960 GPa. extrapolation not needed. density: 40409 kg/m^3, entropy: 942 J/K/kg, internal energy: 15305 kJ/kg
# P= 9970 GPa. extrapolation not needed. density: 40427 kg/m^3, entropy: 943 J/K/kg, internal energy: 15307 kJ/kg
# P= 9980 GPa. extrapolation not needed. density: 40444 kg/m^3, entropy: 943 J/K/kg, internal energy: 15308 kJ/kg
# P= 9990 GPa. extrapolation not needed. density: 40461 kg/m^3, entropy: 943 J/K/kg, internal energy: 15309 kJ/kg
# P= 10000 GPa. extrapolation not needed. density: 40478 kg/m^3, entropy: 943 J/K/kg, internal energy: 15311 kJ/kg

# %%
# save files 

np.savetxt('rho_Fel_ichikawa2014.txt',rho_table)
np.savetxt('s_Fel_ichikawa2014.txt',s_table)
np.savetxt('Eth_Fel_ichikawa2014.txt',Eth_table)
np.savetxt('alpha_Fel_ichikawa2014.txt',alpha_table)
np.savetxt('cV_Fel_ichikawa2014.txt',cV_table)
np.savetxt('cP_Fel_ichikawa2014.txt',cP_table)
np.savetxt('KT_Fel_ichikawa2014.txt',KT_table)
np.savetxt('Pgrid_Fel_ichikawa2014.txt',np.transpose([P_grid_GPa*1e9]))
np.savetxt('Tgrid_Fel_ichikawa2014.txt',np.transpose([T_extrap]))

# %%
######### not quite sure. 

###### need to think about how to find S0
# S0 doesn't technically exsit for liquid Fe. 

def S_function(V, T, T_ref, S0):
    """
    Returns the entropy S(V,T) with an arbitrary integration constant S0.
    
    S(V,T) = 3 n R ln(T/T_ref) + 2 a e0 (V/V0)^g (T - T_ref) + S0.
    """
    return 3 * n * R * math.log(T / T_ref) + 2 * a * e0 * (V / V0)**g * (T - T_ref) + S0

# Suppose we choose T_ref = 7000 K (as before) and we wish to calibrate S such that
# S(V*, T*) = 0 at some reference state (V*, T*). For example, if you have a reference state
# from experiment or another theoretical calculation, set:
T_star = 5000.0       # for example, 5000 K
V_star = 1.0e-5       # for example, 1.0e-5 m^3/mol
# Determine S0 so that S(V_star, T_star)=0:
S0 = - (3 * n * R * math.log(T_star / 7000.0) +
        2 * a * e0 * (V_star / V0)**g * (T_star - 7000.0))

print("Integration constant S0 set to:", S0, "J/(mol·K)")

# Now, if you want to find for a given V the temperature T_zero where S(V,T_zero)=0,
# define a function of T for a fixed V.
def find_T_zero(V, T_ref, S0, T_low=1.0, T_high=1e5):
    """
    Finds T such that S(V, T) = 0 for given V, using S_function.
    """
    f = lambda T: S_function(V, T, T_ref, S0)
    sol = root_scalar(f, bracket=[T_low, T_high], method='brentq')
    if sol.converged:
        return sol.root
    else:
        raise RuntimeError("Failed to find T_zero for S=0")

# For example, for V = V_star, find T_zero:
T_zero = find_T_zero(V_star, 7000.0, S0)
print("For V =", V_star, "m^3/mol, the temperature where S=0 is approximately", T_zero, "K")
